# %%
import os

target_dir = r"C:/Users/kotat/MyPrograms/MyKuzushiji/kuzushiji-recognition/char_sep_datas"

def get_folders(target_dir):
    # ディレクトリだけを抽出
    folders = [
        name for name in os.listdir(target_dir)
        if os.path.isdir(os.path.join(target_dir, name))
    ]
    return folders
folders = get_folders(target_dir)
print(folders)  # フォルダ名の一覧を表示
# Out:
# ['100241706', '100249371', '100249376', '100249416', '100249476', '100249537', '200003076', '200003803', '200003967', '200004107', '200004148', '200005598', '200005798', '200006663', '200006665', '200008003', '200008316', '200010454', '200014685', '200014740', '200015779', '200015843', '200017458', '200018243', '200019865', '200020019', '200021063', '200021071', '200021086', '200021637', '200021644', '200021660', '200021712', '200021763', '200021802', '200021851', '200021853', '200021869', '200021925', '200022050', '200025191', 'brsk00000', 'hnsd00000', 'umgy00000']

# %%
def get_images_path(target_dir, folders_id):
    target_doc = target_dir + '/' + folders_id
    target_images_path = target_doc + '/images'
    return target_doc, target_images_path
target_doc, target_images_path = get_images_path(target_dir, folders[0])
target_doc, target_images_path
# Out:
# ('C:/Users/kotat/MyPrograms/MyKuzushiji/kuzushiji-recognition/char_sep_datas/100241706',
#  'C:/Users/kotat/MyPrograms/MyKuzushiji/kuzushiji-recognition/char_sep_datas/100241706/images')

# %%
import glob
import pandas as pd

def get_doc_df(target_doc):
        # target_doc 内の CSV ファイルをすべて取得
    csv_files = glob.glob(os.path.join(target_doc, "*.csv"))

    # 1つ目の CSV を読み込む例
    if csv_files:
        df = pd.read_csv(csv_files[0], encoding="utf-8")  # 必要なら encoding を調整
        # display(df)
    else:
        print("CSV ファイルが見つかりませんでした。")
    return df
df = get_doc_df(target_doc)
display(df)
# Out:
#      Unicode              Image     X     Y Block ID Char ID  Width  Height
# 0     U+81EA  100241706_00004_2  1852  1736    B0001   C0001    104     219
# 1     U+5E8F  100241706_00004_2  1816  2096    B0001   C0002    152     296
# 2     U+82E5  100241706_00004_2  1465   951    B0001   C0003    172     216
# 3     U+3044  100241706_00004_2  1495  1218    B0001   C0004    143      69
# 4     U+6642  100241706_00004_2  1465  1338    B0001   C0005    168     179
# ...      ...                ...   ...   ...      ...     ...    ...     ...
# 8522  U+5BAE  100241706_00038_1   355  2507    B0001   C0042    145     184
# 8523  U+5C4B  100241706_00038_1   359  2825    B0001   C0043    141     165
# 8524  U+6E90  100241706_00038_1   340  3044    B0001   C0044    152     149
# 8525  U+5175  100241706_00038_1   348  3240    B0001   C0045    148     151
# 8526  U+885B  100241706_00038_1   331  3415    B0001   C0046    203     193
#
# [8527 rows x 8 columns]

# %%
def get_images_id(target_dir):
    # ディレクトリだけを抽出
    folders = [
        name for name in os.listdir(target_dir)
        if os.path.isfile(os.path.join(target_dir, name))
    ]
    return folders
images_id_list = get_images_id(target_images_path)
print(images_id_list)
# Out:
# ['100241706_00001_1.jpg', '100241706_00002_1.jpg', '100241706_00002_2.jpg', '100241706_00003_1.jpg', '100241706_00003_2.jpg', '100241706_00004_1.jpg', '100241706_00004_2.jpg', '100241706_00005_1.jpg', '100241706_00005_2.jpg', '100241706_00006_1.jpg', '100241706_00006_2.jpg', '100241706_00007_1.jpg', '100241706_00007_2.jpg', '100241706_00008_1.jpg', '100241706_00008_2.jpg', '100241706_00009_1.jpg', '100241706_00009_2.jpg', '100241706_00010_1.jpg', '100241706_00010_2.jpg', '100241706_00011_1.jpg', '100241706_00011_2.jpg', '100241706_00012_1.jpg', '100241706_00012_2.jpg', '100241706_00013_1.jpg', '100241706_00013_2.jpg', '100241706_00014_1.jpg', '100241706_00014_2.jpg', '100241706_00015_1.jpg', '100241706_00015_2.jpg', '100241706_00016_1.jpg', '100241706_00016_2.jpg', '100241706_00017_1.jpg', '100241706_00017_2.jpg', '100241706_00018_1.jpg', '100241706_00018_2.jpg', '100241706_00019_1.jpg', '100241706_00019_2.jpg', '100241706_00020_1.jpg', '100241706_00020_2.jpg', '100241706_00021_1.jpg', '100241706_00021_2.jpg', '100241706_00022_1.jpg', '100241706_00022_2.jpg', '100241706_00023_1.jpg', '100241706_00023_2.jpg', '100241706_00024_1.jpg', '100241706_00024_2.jpg', '100241706_00025_1.jpg', '100241706_00025_2.jpg', '100241706_00026_1.jpg', '100241706_00026_2.jpg', '100241706_00027_1.jpg', '100241706_00027_2.jpg', '100241706_00028_1.jpg', '100241706_00028_2.jpg', '100241706_00029_1.jpg', '100241706_00029_2.jpg', '100241706_00030_1.jpg', '100241706_00030_2.jpg', '100241706_00031_1.jpg', '100241706_00031_2.jpg', '100241706_00032_1.jpg', '100241706_00032_2.jpg', '100241706_00033_1.jpg', '100241706_00033_2.jpg', '100241706_00034_1.jpg', '100241706_00034_2.jpg', '100241706_00035_1.jpg', '100241706_00035_2.jpg', '100241706_00036_1.jpg', '100241706_00036_2.jpg', '100241706_00037_1.jpg', '100241706_00037_2.jpg', '100241706_00038_1.jpg', '100241706_00038_2.jpg', '100241706_00039_1.jpg', '100241706_00039_2.jpg', '100241706_00040_1.jpg']

# %%
def get_image_path(target_images_path, image_id):
    image_path = target_images_path + '/' + image_id
    return image_path
def get_image_id(image_path):
    return image_path.split('.')[0]
i = 12
image_path = get_image_path(target_images_path, images_id_list[i])
image_id = get_image_id(images_id_list[i])
image_path, image_id
# Out:
# ('C:/Users/kotat/MyPrograms/MyKuzushiji/kuzushiji-recognition/char_sep_datas/100241706/images/100241706_00007_2.jpg',
#  '100241706_00007_2')

# %%
def get_annotation_data(df, image_id):
    annotation_data = df[df['Image'] == image_id]
    return annotation_data
annotation_data_df = get_annotation_data(df, image_id)
display(annotation_data_df)
# Out:
#     Unicode              Image     X     Y Block ID Char ID  Width  Height
# 297  U+865A  100241706_00007_2  1831   936    B0001   C0001    168     167
# 298  U+5357  100241706_00007_2  1861  1124    B0001   C0002    108     167
# 299  U+7559  100241706_00007_2  1848  1305    B0001   C0003    127     153
# 300  U+5225  100241706_00007_2  1848  1479    B0001   C0004    116     145
# 301  U+5FD7  100241706_00007_2  1871  1619    B0001   C0005    120     140
# ..      ...                ...   ...   ...      ...     ...    ...     ...
# 459  U+306B  100241706_00007_2   176  2979    B0001   C0163    121      80
# 460  U+4ED8  100241706_00007_2   200  3087    B0001   C0164     77     141
# 461  U+3066  100241706_00007_2   215  3231    B0001   C0165     40     104
# 462  U+98DF  100241706_00007_2   177  3344    B0001   C0166    129     148
# 463  U+3075  100241706_00007_2   183  3493    B0001   C0167    104     103
#
# [167 rows x 8 columns]

# %%
from PIL import Image
import numpy as np
import torch
from matplotlib import pyplot as plt


def get_image(image_path, target_width=1024, patch_size=256):
    """
    image_path から画像を読み込み、
    - 横幅を target_width にリサイズ
    - 高さを patch_size(=256) の倍数になるように下側にゼロパディング
    を行ってから torch.Tensor(C, H, W) を返す。
    """
    # 画像読み込み (RGB)
    img = Image.open(image_path).convert("RGB")

    # 元のサイズ
    orig_w, orig_h = img.size  # (W, H)

    # 横幅を target_width に変更し、高さは縦横比を維持してスケーリング
    new_w = target_width
    new_h = int(orig_h * new_w / orig_w)
    img = img.resize((new_w, new_h), Image.BILINEAR)

    # 高さを patch_size の倍数にパディング
    padded_h = ((new_h + patch_size - 1) // patch_size) * patch_size  # 切り上げ
    pad_bottom = padded_h - new_h

    if pad_bottom > 0:
        # (W, H+C) へのパディング用キャンバス（黒で埋める）
        padded = Image.new("RGB", (new_w, padded_h), (0, 0, 0))
        padded.paste(img, (0, 0))
        img = padded

    # Tensor 変換: (H, W, C) -> (C, H, W), float32
    tensor = torch.from_numpy(np.array(img)).permute(2, 0, 1).float()
    return tensor, orig_w, orig_h

# 使用例
image_path = get_image_path(target_images_path, images_id_list[i])
img, orig_w, orig_h = get_image(image_path, target_width=1024, patch_size=256)
plt.imshow(img.permute(1, 2, 0).byte())
plt.show()
img.shape
# Out:
# torch.Size([3, 1792, 1024])

# %%
def draw_rects_from_df(df, canvas_width, orig_w, orig_h):
    """
    df から矩形を読み取り、(H, W) の torch.float32 テンソルを返す。
    矩形領域は 1、それ以外は 0。
    """
    x_col="X"
    y_col="Y"
    w_col="Width"
    h_col="Height"

    org_height = orig_h
    org_width = orig_w
    canvas_height = int(org_height * canvas_width / org_width)
    canvas = torch.zeros((canvas_height, canvas_width), dtype=torch.float32)

    rate = canvas_width / org_width

    for _, row in df.iterrows():
        x = int(row[x_col] * rate)
        y = int(row[y_col] * rate)
        w = int(row[w_col] * rate)
        h = int(row[h_col] * rate)

        # 範囲チェック（キャンバス外にはみ出る場合の対策）
        x1 = max(x, 0)
        y1 = max(y, 0)
        x2 = min(x + w, canvas_width)
        y2 = min(y + h, canvas_height)

        if x1 < x2 and y1 < y2:
            canvas[y1:y2, x1:x2] = 1.0

    return canvas

# 例: 画像サイズが 1024x1024 の場合
canvas_width = 1024
canvas = draw_rects_from_df(annotation_data_df, canvas_width, orig_w, orig_h)
plt.imshow(canvas, cmap='gray')
plt.show()

# %%
def draw_glue_from_df(df, canvas_width, orig_w, orig_h):
    """
    df から矩形を読み取り、(H, W) の torch.float32 テンソルを返す。
    矩形領域は 1、それ以外は 0。
    """
    x_col="X"
    y_col="Y"
    w_col="Width"
    h_col="Height"

    org_height = orig_h
    org_width = orig_w
    canvas_height = int(org_height * canvas_width / org_width)
    canvas = torch.zeros((canvas_height, canvas_width), dtype=torch.float32)

    rate = canvas_width / org_width

    for _, row in df.iterrows():
        x = int(row[x_col] * rate)
        y = int(row[y_col] * rate)
        w = int(row[w_col] * rate)
        h = int(row[h_col] * rate)
        min_l = int(min(w, h)*0.2)

        # 範囲チェック（キャンバス外にはみ出る場合の対策）
        x1 = max(x, 0)
        y1 = max(y, 0) - min_l
        x2 = min(x + w , canvas_width)
        y2 = min(y + h + min_l, canvas_height)

        if x1 < x2 and y1 < y2:
            canvas[y1:y2, x1:x2] += 1.0
    canvas = (canvas == 2).to(torch.float32)  # or .to(tensor.dtype)

    return canvas

# 例: 画像サイズが 1024x1024 の場合
canvas_width = 1024
canvas = draw_glue_from_df(annotation_data_df, canvas_width, orig_w, orig_h)
plt.imshow(canvas, cmap='gray')
plt.show()

# %%
# target_dir = r"C:/Users/kotat/MyPrograms/MyKuzushiji/kuzushiji-recognition/char_sep_datas"
# # フォルダ一覧を取得
# folders = get_folders(target_dir)
# for folder in folders:
#     # ドキュメントパスと、画像パスを取得
#     target_doc, target_images_path = get_images_path(target_dir, folder)
#     df = get_doc_df(target_doc)
#     images_name_list = get_images_id(target_images_path)
#     for image_name in images_name_list:
#         image_path = get_image_path(target_images_path, image_name)
#         image_id = get_image_id(image_name)
#         img = get_image(image_path)
#         annotation_data_df = get_annotation_data(df,image_id)
#         canvas_width = 1024
#         cnavas_main  = draw_rects_from_df(annotation_data_df, img, canvas_width)
#         canvas_glue = draw_glue_from_df(annotation_data_df, img, canvas_width)
#         # ここで canvas を保存または処理するコードを追加できます
#         # plt.subplot(1, 3, 1)
#         # plt.imshow(img.permute(1, 2, 0).byte())
#         # plt.title('Original Image') 
#         # plt.subplot(1, 3, 2)
#         # plt.imshow(cnavas_main, cmap='gray')
#         # plt.title('Main Rectangles')
#         # plt.subplot(1, 3, 3)  
#         # plt.imshow(canvas_glue, cmap='gray')
#         # plt.title('Glue Rectangles')
#         # plt.show()
#         canvas = torch.stack([cnavas_main, canvas_glue], dim=0)
#         print(canvas.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 15
#      13 annotation_data_df = get_annotation_data(df,image_id)
#      14 canvas_width = 1024
# ---> 15 cnavas_main  = draw_rects_from_df(annotation_data_df, img, canvas_width)
#      16 canvas_glue = draw_glue_from_df(annotation_data_df, img, canvas_width)
#      17 # ここで canvas を保存または処理するコードを追加できます
#      18 # plt.subplot(1, 3, 1)
#      19 # plt.imshow(img.permute(1, 2, 0).byte())
#    (...)
#      26 # plt.title('Glue Rectangles')
#      27 # plt.show()
#
# TypeError: draw_rects_from_df() missing 1 required positional argument: 'orig_h'

# %% [markdown]
# # データセットの定義

# %%
# ...existing code...
from torch.utils.data import Dataset, DataLoader

class KuzushijiCanvasDataset(Dataset):
    def __init__(self, root_dir, canvas_width=1024, transform=None, test_mode= False, test_docs=[]):
        """
        root_dir: char_sep_datas のパス
        canvas_width: キャンバス幅（高さは画像縦横比から計算）
        transform: 画像に対する torchvision.transforms など（任意）
        """
        self.root_dir = root_dir
        self.canvas_width = canvas_width
        self.transform = transform
        test_docs = set(test_docs)

        # ファイル一覧を作る
        # 形式: [(image_path, df_for_that_folder), ...] とする
        self.samples = []

        folders = get_folders(root_dir)
        for folder in folders:
            if test_mode:
                if folder not in test_docs:
                    continue
            else:
                if folder in test_docs:
                    continue
            target_doc, target_images_path = get_images_path(root_dir, folder)
            df = get_doc_df(target_doc)
            image_name_list = get_images_id(target_images_path)
            for image_name in image_name_list:
                image_path = get_image_path(target_images_path, image_name)
                image_id = get_image_id(image_name)  # 拡張子なし
                # DataFrame 側の Image 列と合わせる (必要に応じて調整)
                # 例: df['Image'] が拡張子なしならそのまま、拡張子付きなら ".png" を足すなど
                self.samples.append({
                    "image_path": image_path,
                    "image_id": image_id,
                    "df": df
                })

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        sample = self.samples[idx]
        image_path = sample["image_path"]
        image_id = sample["image_id"]
        df = sample["df"]

        # 画像ロード
        img, orig_w, orig_h = get_image(image_path, target_width=self.canvas_width,patch_size=256)  # (C, H, W) tensor

        img = img / 255.0  # 0-1 正規化
        # 必要なら変換
        if self.transform is not None:
            img = self.transform(img)

        # アノテーション抽出
        ann_df = get_annotation_data(df, image_id)

        # キャンバス生成
        canvas_main = draw_rects_from_df(ann_df, self.canvas_width, orig_w, orig_h)
        canvas_glue = draw_glue_from_df(ann_df, self.canvas_width, orig_w, orig_h)
        canvas = torch.stack([canvas_main, canvas_glue], dim=0)  # (2, Hc, Wc)

        return img, canvas

test_docs = [
    '200021637',
    '100249371',
    '100249537',
    '200005598',
    '200014740',
    '200020019',
    '200021712',
    '200021869'
]

# データセットとデータローダの作成例
train_dataset = KuzushijiCanvasDataset(
    root_dir=target_dir,
    canvas_width=2048,
    transform=None,  # ここに正規化などを入れてもよい
    test_mode=False,
    test_docs=test_docs
)
test_dataset = KuzushijiCanvasDataset(
    root_dir=target_dir,
    canvas_width=2048,
    transform=None,  # ここに正規化などを入れてもよい
    test_mode=True,
    test_docs=test_docs
)

train_dataloader = DataLoader(
    train_dataset,
    batch_size=1,
    shuffle=True,
    num_workers=0  # Windows なら最初は 0 推奨
)
test_dataloader = DataLoader(
    test_dataset,
    batch_size=1,
    shuffle=False,
    num_workers=0  # Windows なら最初は 0 推奨
)

# # 動作確認
# for imgs, canvases in dataloader:
#     print(imgs.shape)     # (B, C, H, W)
#     print(canvases.shape) # (B, 2, Hc, Wc)
    # break
# ...existing code...

# %%
print(len(train_dataset))
print(len(test_dataset))
# Out:
# 5204
# 947

# %%
import torch.nn.functional as F

def patchify_image(img, patch_size=256):
    """
    img: (C, H, W) tensor
    return: patches: (N_patches, C, patch_size, patch_size)
    """
    C, H, W = img.shape
    assert H % patch_size == 0 and W % patch_size == 0, "H, W は patch_size の倍数を想定"

    # (1, C, H, W) -> unfold
    img = img.unsqueeze(0)
    patches = img.unfold(2, patch_size, patch_size).unfold(3, patch_size, patch_size)
    # shape: (1, C, H//p, W//p, p, p)
    patches = patches.contiguous().view(
        -1, C, patch_size, patch_size
    )  # (N_patches, C, p, p)
    return patches

def patchify_canvas(canvas, patch_size=256):
    """
    canvas: (K, Hc, Wc)  (K=2 チャネル)
    まず Hc, Wc を画像サイズ (H, W) に合わせておくことを推奨。
    ここでは単純に patch_size の倍数と仮定。
    return: (N_patches, K, patch_size, patch_size)
    """
    K, Hc, Wc = canvas.shape
    assert Hc % patch_size == 0 and Wc % patch_size == 0, "Hc, Wc は patch_size の倍数を想定"

    canvas = canvas.unsqueeze(0)  # (1, K, Hc, Wc)
    patches = canvas.unfold(2, patch_size, patch_size).unfold(3, patch_size, patch_size)
    patches = patches.contiguous().view(
        -1, K, patch_size, patch_size
    )  # (N_patches, K, p, p)
    return patches

# %% [markdown]
# # Transformer

# %%
# ...existing code...
import torch.nn as nn

class PatchTransformer(nn.Module):
    def __init__(self, img_channels=3, patch_size=256, d_model=256,
                 nhead=8, num_layers=4, num_classes=2):
        super().__init__()
        self.patch_size = patch_size
        self.img_channels = img_channels

        patch_dim = img_channels * patch_size * patch_size  # 3*256*256
        self.patch_embed = nn.Linear(patch_dim, d_model)

        # 位置埋め込み（最大パッチ数を仮に 256 としておく）
        max_patches = 16384
        self.pos_embed = nn.Parameter(torch.zeros(1, max_patches, d_model))

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=nhead, batch_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        # 各パッチからクラスを予測（例: 2クラス）
        self.cls_head = nn.Linear(d_model, num_classes)

    def forward(self, img):
        """
        img: (B, 3, H, W)
        return: logits: (B, N_patches, num_classes)
        """
        B, C, H, W = img.shape
        p = self.patch_size

        assert H % p == 0 and W % p == 0
        n_h = H // p
        n_w = W // p
        n_patches = n_h * n_w
        assert n_patches <= self.pos_embed.size(1), "max_patches を増やす必要あり"

        # パッチ分割: (B, C, H, W) -> (B, n_h*n_w, C*p*p)
        x = img.unfold(2, p, p).unfold(3, p, p)  # (B, C, n_h, n_w, p, p)
        x = x.contiguous().view(B, C, n_h * n_w, p * p)  # (B, C, N, p*p)
        x = x.permute(0, 2, 1, 3).contiguous().view(B, n_patches, -1)  # (B, N, C*p*p)
        # 埋め込み
        x = self.patch_embed(x)  # (B, N, d_model)

        # 位置埋め込み加算
        x = x + self.pos_embed[:, :n_patches, :]

        # Transformer Encoder
        x = self.encoder(x)  # (B, N, d_model)

        # 各パッチのクラス予測
        logits = self.cls_head(x)  # (B, N, num_classes)
        return logits

# %%
def make_patch_labels(canvas, patch_size=256, threshold=0.5):
    """
    canvas: (2, Hc, Wc)
    glue チャネル (index=1) を見て、パッチの平均値 > threshold なら 1, それ以外 0
    return: labels: (N_patches,) long tensor
    """
    K, Hc, Wc = canvas.shape
    assert K == 2
    glue = canvas[1:2]  # (1, Hc, Wc)

    # パッチ分割
    patches = patchify_canvas(glue, patch_size=patch_size)  # (N, 1, p, p)
    # 平均値
    mean_vals = patches.mean(dim=(1, 2, 3))  # (N,)
    labels = (mean_vals > threshold).long()
    return labels

def make_patch_labels_multi(canvas, patch_size=256, threshold=0.3):
    """
    canvas: (2, Hc, Wc)  [0: main, 1: glue]
    各パッチについて、main / glue の平均値 > threshold なら 1, それ以外 0
    return: labels: (N_patches, 2) float tensor in {0,1}
    """
    K, Hc, Wc = canvas.shape
    assert K == 2

    # パッチ分割: (2, Hc, Wc) -> (N, 2, p, p)
    patches = patchify_canvas(canvas, patch_size=patch_size)  # (N, 2, p, p)

    # チャネルごとに平均値: (N, 2)
    mean_vals = patches.mean(dim=(2, 3))

    # threshold を超えたら 1、それ以外 0
    labels = (mean_vals > threshold).float()  # (N, 2)

    return labels

# %% [markdown]
# ## 学習

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

patch_size = 256
model = PatchTransformer(
    img_channels=3,
    patch_size=patch_size,
    d_model=256,
    nhead=8,
    num_layers=4,
    num_classes=2    # 2チャネル: [main, glue]
).to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

history = {'train_loss':[], 'val_loss':[]}

ckpt_dir = 'checkpoints_PatchTransformer'
os.makedirs(ckpt_dir, exist_ok=True)

num_epochs = 100
for epoch in range(num_epochs):  
    model.train()
    running_loss = 0.0
    n_batches = 0
    
    for imgs, canvases in train_dataloader:
        imgs = imgs.to(device)         # (B, 3, H, W)
        canvases = canvases.to(device) # (B, 2, Hc, Wc)

        B, C, H, W = imgs.shape

        # キャンバスを画像サイズにリサイズ → ピクセルごとの 0/1 ラベル
        target = F.interpolate(
            canvases, size=(H, W), mode="nearest"
        )  # (B, 2, H, W)

        # 順伝播
        logits = model(imgs)  # (B, 2, H, W)

        loss = criterion(logits, target.float())
        history.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        n_batches += 1

        # break 
 
    train_epoch_loss = running_loss / n_batches
    history['train_loss'].append(train_epoch_loss)

    model.eval()
    val_running_loss = 0.0
    val_n_batches = 0
    with torch.no_grad():
        for imgs, canvases in test_dataloader:
            imgs = imgs.to(device)
            canvases = canvases.to(device)

            B, C, H, W = imgs.shape
            target = F.interpolate(
                canvases, size=(H,W), mode= 'nearest'
            )

            logits = model(imgs)
            val_loss = criterion(logits, target.float())

            val_running_loss += val_loss.item()
            val_n_batches += 1
    val_epoch_loss = val_running_loss / val_n_batches
    history['val_loss'].append(val_epoch_loss)

    print(
        f'Epoch [{epoch+1}/{num_epochs}]',
        f'Train Loss: {train_epoch_loss:.4f} Val Loss: {val_epoch_loss:.4f}')

    ckpt_path = os.path.join(ckpt_dir, f'epoch_{epoch+1}.pth')
    torch.save(
        {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'history': history,
        },
        ckpt_path,
    )
    print(f'saved checkpoint: {ckpt_path}')

# ...existing code...
plt.plot(history['train_loss'], label='train')
plt.plot(history['val_loss'], label='val')
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.title("PatchTransformerSeg Loss")
plt.legend()
plt.show()
# Out:
# loss: 0.8157679438591003
# loss: 0.30467790365219116
# loss: 0.30467790365219116
# loss: 0.4489763677120209
# loss: 0.4489763677120209
# loss: 0.3271414339542389
# loss: 0.3271414339542389
# loss: 0.4228382408618927
# loss: 0.4228382408618927
# loss: 0.10823919624090195
# loss: 0.10823919624090195
# loss: 0.10661249607801437
# loss: 0.10661249607801437
# loss: 0.09054303169250488
# loss: 0.09054303169250488
# loss: 0.42483603954315186
# loss: 0.42483603954315186
# loss: 0.3289634883403778
# loss: 0.3289634883403778
# loss: 0.1440490037202835
# loss: 0.1440490037202835
# loss: 0.054670531302690506
# loss: 0.054670531302690506
# loss: 0.41730329394340515
# loss: 0.41730329394340515
# loss: 0.41940075159072876
# loss: 0.41940075159072876
# loss: 0.3727400600910187
# loss: 0.3727400600910187
# loss: 0.3137452304363251
# loss: 0.3137452304363251
# loss: 0.37654560804367065
# loss: 0.37654560804367065
# loss: 0.0650499016046524
# loss: 0.0650499016046524
# loss: 0.3576488792896271
# loss: 0.3576488792896271
# loss: 0.38757526874542236
# loss: 0.38757526874542236
# loss: 0.38281577825546265
# loss: 0.38281577825546265
# loss: 0.3775476813316345
# loss: 0.3775476813316345
# loss: 0.3630843460559845
# loss: 0.3630843460559845
# loss: 0.35512831807136536
# loss: 0.35512831807136536
# loss: 0.13932077586650848
# loss: 0.13932077586650848
# loss: 0.35847532749176025
# loss: 0.35847532749176025
# loss: 0.32694292068481445
# loss: 0.32694292068481445
# loss: 0.3449491858482361
# loss: 0.3449491858482361
# loss: 0.35109657049179077
# loss: 0.35109657049179077
# loss: 0.3203688859939575
# loss: 0.3203688859939575
# loss: 0.37674590945243835
# loss: 0.37674590945243835
# loss: 0.3178962767124176
# loss: 0.3178962767124176
# loss: 0.315606951713562
# loss: 0.315606951713562
# loss: 0.32298028469085693
# loss: 0.32298028469085693
# loss: 0.3978334367275238
# loss: 0.3978334367275238
# loss: 0.3831871747970581
# loss: 0.3831871747970581
# loss: 0.3057343661785126
# loss: 0.3057343661785126
# loss: 0.34715619683265686
# loss: 0.34715619683265686
# loss: 0.3408721387386322
# loss: 0.3408721387386322
# loss: 0.2926781177520752
# loss: 0.2926781177520752
# loss: 0.31368452310562134
# loss: 0.31368452310562134
# loss: 0.43227848410606384
# loss: 0.43227848410606384
# loss: 0.32552310824394226
# loss: 0.32552310824394226
# loss: 0.11338949203491211
# loss: 0.11338949203491211
# loss: 0.10532854497432709
# loss: 0.10532854497432709
# loss: 0.09739793837070465
# loss: 0.09739793837070465
# loss: 0.3536187708377838
# loss: 0.3536187708377838
# loss: 0.3582793176174164
# loss: 0.3582793176174164
# loss: 0.32175999879837036
# loss: 0.32175999879837036
# loss: 0.062438055872917175
# loss: 0.062438055872917175
# loss: 0.3753259778022766
# loss: 0.3753259778022766
# loss: 0.3759058117866516
# loss: 0.3759058117866516
# loss: 0.4547910988330841
# loss: 0.4547910988330841
# loss: 0.3524698317050934
# loss: 0.3524698317050934
# loss: 0.40224745869636536
# loss: 0.40224745869636536
# loss: 0.36101290583610535
# loss: 0.36101290583610535
# loss: 0.08853030949831009
# loss: 0.08853030949831009
# loss: 0.35426416993141174
# loss: 0.35426416993141174
# loss: 0.31491193175315857
# loss: 0.31491193175315857
# loss: 0.10660110414028168
# loss: 0.10660110414028168
# loss: 0.3701511025428772
# loss: 0.3701511025428772
# loss: 0.3114093244075775
# loss: 0.3114093244075775
# loss: 0.36918729543685913
# loss: 0.36918729543685913
# loss: 0.1741756796836853
# loss: 0.1741756796836853
# loss: 0.4309387505054474
# loss: 0.4309387505054474
# loss: 0.10065476596355438
# loss: 0.10065476596355438
# loss: 0.2931469678878784
# loss: 0.2931469678878784
# loss: 0.31880494952201843
# loss: 0.31880494952201843
# loss: 0.40561261773109436
# loss: 0.40561261773109436
# loss: 0.32792869210243225
# loss: 0.32792869210243225
# loss: 0.36505502462387085
# loss: 0.36505502462387085
# loss: 0.30207034945487976
# loss: 0.30207034945487976
# loss: 0.33460089564323425
# loss: 0.33460089564323425
# loss: 0.32402870059013367
# loss: 0.32402870059013367
# loss: 0.31031331419944763
# loss: 0.31031331419944763
# loss: 0.33373746275901794
# loss: 0.33373746275901794
# loss: 0.33548370003700256
# loss: 0.33548370003700256
# loss: 0.3033922016620636
# loss: 0.3033922016620636
# loss: 0.33469948172569275
# loss: 0.33469948172569275
# loss: 0.29724231362342834
# loss: 0.29724231362342834
# loss: 0.1160498633980751
# loss: 0.1160498633980751
# loss: 0.3158777952194214
# loss: 0.3158777952194214
# loss: 0.33173617720603943
# loss: 0.33173617720603943
# loss: 0.2997812032699585
# loss: 0.2997812032699585
# loss: 0.3663410544395447
# loss: 0.3663410544395447
# loss: 0.3555360734462738
# loss: 0.3555360734462738
# loss: 0.37555718421936035
# loss: 0.37555718421936035
# loss: 0.34674257040023804
# loss: 0.34674257040023804
# loss: 0.30963629484176636
# loss: 0.30963629484176636
# loss: 0.29948288202285767
# loss: 0.29948288202285767
# loss: 0.10786302387714386
# loss: 0.10786302387714386
# loss: 0.11106559634208679
# loss: 0.11106559634208679
# loss: 0.37706875801086426
# loss: 0.37706875801086426
# loss: 0.3364514708518982
# loss: 0.3364514708518982
# loss: 0.3538731634616852
# loss: 0.3538731634616852
# loss: 0.33958232402801514
# loss: 0.33958232402801514
# loss: 0.08417834341526031
# loss: 0.08417834341526031
# loss: 0.44773831963539124
# loss: 0.44773831963539124
# loss: 0.34412869811058044
# loss: 0.34412869811058044
# loss: 0.3410598933696747
# loss: 0.3410598933696747
# loss: 0.3940916955471039
# loss: 0.3940916955471039
# loss: 0.3363679051399231
# loss: 0.3363679051399231
# loss: 0.3764382600784302
# loss: 0.3764382600784302
# loss: 0.29960671067237854
# loss: 0.29960671067237854
# loss: 0.312945157289505
# loss: 0.312945157289505
# loss: 0.3491210341453552
# loss: 0.3491210341453552
# loss: 0.3542119562625885
# loss: 0.3542119562625885
# loss: 0.38043978810310364
# loss: 0.38043978810310364
# loss: 0.14922544360160828
# loss: 0.14922544360160828
# loss: 0.12911689281463623
# loss: 0.12911689281463623
# loss: 0.3037421405315399
# loss: 0.3037421405315399
# loss: 0.37344294786453247
# loss: 0.37344294786453247
# loss: 0.08895360678434372
# loss: 0.08895360678434372
# loss: 0.3241354525089264
# loss: 0.3241354525089264
# loss: 0.3283684551715851
# loss: 0.3283684551715851
# loss: 0.33196160197257996
# loss: 0.33196160197257996
# loss: 0.40644940733909607
# loss: 0.40644940733909607
# loss: 0.3749542534351349
# loss: 0.3749542534351349
# loss: 0.29324865341186523
# loss: 0.29324865341186523
# loss: 0.3658876419067383
# loss: 0.3658876419067383
# loss: 0.3805250823497772
# loss: 0.3805250823497772
# loss: 0.3833697438240051
# loss: 0.3833697438240051
# loss: 0.37955790758132935
# loss: 0.37955790758132935
# loss: 0.10774208605289459
# loss: 0.10774208605289459
# loss: 0.24824559688568115
# loss: 0.24824559688568115
# loss: 0.10895621031522751
# loss: 0.10895621031522751
# loss: 0.340438574552536
# loss: 0.340438574552536
# loss: 0.39295729994773865
# loss: 0.39295729994773865
# loss: 0.10102762281894684
# loss: 0.10102762281894684
# loss: 0.36915865540504456
# loss: 0.36915865540504456
# loss: 0.3230556845664978
# loss: 0.3230556845664978
# loss: 0.09432213753461838
# loss: 0.09432213753461838
# loss: 0.08603861182928085
# loss: 0.08603861182928085
# loss: 0.34175509214401245
# loss: 0.34175509214401245
# loss: 0.2382589727640152
# loss: 0.2382589727640152
# loss: 0.3665589988231659
# loss: 0.3665589988231659
# loss: 0.3977903425693512
# loss: 0.3977903425693512
# loss: 0.3281780183315277
# loss: 0.3281780183315277
# loss: 0.3273060917854309
# loss: 0.3273060917854309
# loss: 0.42129552364349365
# loss: 0.42129552364349365
# loss: 0.39238426089286804
# loss: 0.39238426089286804
# loss: 0.31853896379470825
# loss: 0.31853896379470825
# loss: 0.07966771721839905
# loss: 0.07966771721839905
# loss: 0.32186898589134216
# loss: 0.32186898589134216
# loss: 0.08547749370336533
# loss: 0.08547749370336533
# loss: 0.30169442296028137
# loss: 0.30169442296028137
# loss: 0.3203452527523041
# loss: 0.3203452527523041
# loss: 0.3342774212360382
# loss: 0.3342774212360382
# loss: 0.37759000062942505
# loss: 0.37759000062942505
# loss: 0.3355652093887329
# loss: 0.3355652093887329
# loss: 0.10186540335416794
# loss: 0.10186540335416794
# loss: 0.3448149263858795
# loss: 0.3448149263858795
# loss: 0.3572383224964142
# loss: 0.3572383224964142
# loss: 0.2979721426963806
# loss: 0.2979721426963806
# loss: 0.3319125175476074
# loss: 0.3319125175476074
# loss: 0.38990262150764465
# loss: 0.38990262150764465
# loss: 0.3356741964817047
# loss: 0.3356741964817047
# loss: 0.09474002569913864
# loss: 0.09474002569913864
# loss: 0.3148794174194336
# loss: 0.3148794174194336
# loss: 0.4327293932437897
# loss: 0.4327293932437897
# loss: 0.30730801820755005
# loss: 0.30730801820755005
# loss: 0.3360537886619568
# loss: 0.3360537886619568
# loss: 0.0652843564748764
# loss: 0.0652843564748764
# loss: 0.16511979699134827
# loss: 0.16511979699134827
# loss: 0.35322004556655884
# loss: 0.35322004556655884
# loss: 0.3251122534275055
# loss: 0.3251122534275055
# loss: 0.38316449522972107
# loss: 0.38316449522972107
# loss: 0.33346566557884216
# loss: 0.33346566557884216
# loss: 0.34422773122787476
# loss: 0.34422773122787476
# loss: 0.3257550001144409
# loss: 0.3257550001144409
# loss: 0.3041186034679413
# loss: 0.3041186034679413
# loss: 0.3660604655742645
# loss: 0.3660604655742645
# loss: 0.3435571789741516
# loss: 0.3435571789741516
# loss: 0.3703495264053345
# loss: 0.3703495264053345
# loss: 0.36603862047195435
# loss: 0.36603862047195435
# loss: 0.35579797625541687
# loss: 0.35579797625541687
# loss: 0.3243364989757538
# loss: 0.3243364989757538
# loss: 0.2998012602329254
# loss: 0.2998012602329254
# loss: 0.3567248284816742
# loss: 0.3567248284816742
# loss: 0.3678027093410492
# loss: 0.3678027093410492
# loss: 0.3197525143623352
# loss: 0.3197525143623352
# loss: 0.12439876049757004
# loss: 0.12439876049757004
# loss: 0.42787089943885803
# loss: 0.42787089943885803
# loss: 0.3624899983406067
# loss: 0.3624899983406067
# loss: 0.31755331158638
# loss: 0.31755331158638
# loss: 0.3156284987926483
# loss: 0.3156284987926483
# loss: 0.33577877283096313
# loss: 0.33577877283096313
# loss: 0.3191063404083252
# loss: 0.3191063404083252
# loss: 0.28630515933036804
# loss: 0.28630515933036804
# loss: 0.3951854109764099
# loss: 0.3951854109764099
# loss: 0.35617905855178833
# loss: 0.35617905855178833
# loss: 0.09487734735012054
# loss: 0.09487734735012054
# loss: 0.3416515290737152
# loss: 0.3416515290737152
# loss: 0.370859831571579
# loss: 0.370859831571579
# loss: 0.3988701105117798
# loss: 0.3988701105117798
# loss: 0.3635561764240265
# loss: 0.3635561764240265
# loss: 0.3272809684276581
# loss: 0.3272809684276581
# loss: 0.31229671835899353
# loss: 0.31229671835899353
# loss: 0.3221062123775482
# loss: 0.3221062123775482
# loss: 0.322085440158844
# loss: 0.322085440158844
# loss: 0.33133599162101746
# loss: 0.33133599162101746
# loss: 0.37304940819740295
# loss: 0.37304940819740295
# loss: 0.29615914821624756
# loss: 0.29615914821624756
# loss: 0.39969781041145325
# loss: 0.39969781041145325
# loss: 0.3435555398464203
# loss: 0.3435555398464203
# loss: 0.3401521146297455
# loss: 0.3401521146297455
# loss: 0.3040538728237152
# loss: 0.3040538728237152
# loss: 0.36651670932769775
# loss: 0.36651670932769775
# loss: 0.35217124223709106
# loss: 0.35217124223709106
# loss: 0.3668616712093353
# loss: 0.3668616712093353
# loss: 0.36464348435401917
# loss: 0.36464348435401917
# loss: 0.3140697479248047
# loss: 0.3140697479248047
# loss: 0.35468941926956177
# loss: 0.35468941926956177
# loss: 0.33417218923568726
# loss: 0.33417218923568726
# loss: 0.33680459856987
# loss: 0.33680459856987
# loss: 0.10366283357143402
# loss: 0.10366283357143402
# loss: 0.3304005563259125
# loss: 0.3304005563259125
# loss: 0.3503144383430481
# loss: 0.3503144383430481
# loss: 0.33293914794921875
# loss: 0.33293914794921875
# loss: 0.3158496618270874
# loss: 0.3158496618270874
# loss: 0.30378833413124084
# loss: 0.30378833413124084
# loss: 0.09309657663106918
# loss: 0.09309657663106918
# loss: 0.3297240734100342
# loss: 0.3297240734100342
# loss: 0.36922982335090637
# loss: 0.36922982335090637
# loss: 0.31638944149017334
# loss: 0.31638944149017334
# loss: 0.07992374897003174
# loss: 0.07992374897003174
# loss: 0.32420408725738525
# loss: 0.32420408725738525
# loss: 0.08194303512573242
# loss: 0.08194303512573242
# loss: 0.23402780294418335
# loss: 0.23402780294418335
# loss: 0.29047906398773193
# loss: 0.29047906398773193
# loss: 0.41257134079933167
# loss: 0.41257134079933167
# loss: 0.31205692887306213
# loss: 0.31205692887306213
# loss: 0.34159788489341736
# loss: 0.34159788489341736
# loss: 0.35077378153800964
# loss: 0.35077378153800964
# loss: 0.08061888813972473
# loss: 0.08061888813972473
# loss: 0.3738676905632019
# loss: 0.3738676905632019
# loss: 0.30592262744903564
# loss: 0.30592262744903564
# loss: 0.33348384499549866
# loss: 0.33348384499549866
# loss: 0.3104594349861145
# loss: 0.3104594349861145
# loss: 0.29212436079978943
# loss: 0.29212436079978943
# loss: 0.32289791107177734
# loss: 0.32289791107177734
# loss: 0.3552323281764984
# loss: 0.3552323281764984
# loss: 0.37363201379776
# loss: 0.37363201379776
# loss: 0.3029212951660156
# loss: 0.3029212951660156
# loss: 0.3293761610984802
# loss: 0.3293761610984802
# loss: 0.31576403975486755
# loss: 0.31576403975486755
# loss: 0.3713812530040741
# loss: 0.3713812530040741
# loss: 0.3170011043548584
# loss: 0.3170011043548584
# loss: 0.3118431568145752
# loss: 0.3118431568145752
# loss: 0.3360486328601837
# loss: 0.3360486328601837
# loss: 0.3162968158721924
# loss: 0.3162968158721924
# loss: 0.11278314888477325
# loss: 0.11278314888477325
# loss: 0.33054837584495544
# loss: 0.33054837584495544
# loss: 0.338038831949234
# loss: 0.338038831949234
# loss: 0.0905042290687561
# loss: 0.0905042290687561
# loss: 0.3397807776927948
# loss: 0.3397807776927948
# loss: 0.3852197229862213
# loss: 0.3852197229862213
# loss: 0.3441864252090454
# loss: 0.3441864252090454
# loss: 0.07204371690750122
# loss: 0.07204371690750122
# loss: 0.37171152234077454
# loss: 0.37171152234077454
# loss: 0.35790568590164185
# loss: 0.35790568590164185
# loss: 0.36997413635253906
# loss: 0.36997413635253906
# loss: 0.3752528131008148
# loss: 0.3752528131008148
# loss: 0.35745182633399963
# loss: 0.35745182633399963
# loss: 0.3536075949668884
# loss: 0.3536075949668884
# loss: 0.10826748609542847
# loss: 0.10826748609542847
# loss: 0.3398759067058563
# loss: 0.3398759067058563
# loss: 0.10662560909986496
# loss: 0.10662560909986496
# loss: 0.35446897149086
# loss: 0.35446897149086
# loss: 0.10089036822319031
# loss: 0.10089036822319031
# loss: 0.31178784370422363
# loss: 0.31178784370422363
# loss: 0.33012980222702026
# loss: 0.33012980222702026
# loss: 0.3581293225288391
# loss: 0.3581293225288391
# loss: 0.31230705976486206
# loss: 0.31230705976486206
# loss: 0.33256134390830994
# loss: 0.33256134390830994
# loss: 0.39518120884895325
# loss: 0.39518120884895325
# loss: 0.3126373291015625
# loss: 0.3126373291015625
# loss: 0.3277052640914917
# loss: 0.3277052640914917
# loss: 0.3883792459964752
# loss: 0.3883792459964752
# loss: 0.10702934861183167
# loss: 0.10702934861183167
# loss: 0.3153228461742401
# loss: 0.3153228461742401
# loss: 0.3514852523803711
# loss: 0.3514852523803711
# loss: 0.34000006318092346
# loss: 0.34000006318092346
# loss: 0.3022657334804535
# loss: 0.3022657334804535
# loss: 0.30733537673950195
# loss: 0.30733537673950195
# loss: 0.3515412211418152
# loss: 0.3515412211418152
# loss: 0.30612775683403015
# loss: 0.30612775683403015
# loss: 0.3414398729801178
# loss: 0.3414398729801178
# loss: 0.332372784614563
# loss: 0.332372784614563
# loss: 0.1684274971485138
# loss: 0.1684274971485138
# loss: 0.35339608788490295
# loss: 0.35339608788490295
# loss: 0.3164622485637665
# loss: 0.3164622485637665
# loss: 0.3506070375442505
# loss: 0.3506070375442505
# loss: 0.37402644753456116
# loss: 0.37402644753456116
# loss: 0.3263275623321533
# loss: 0.3263275623321533
# loss: 0.11137416958808899
# loss: 0.11137416958808899
# loss: 0.3447377383708954
# loss: 0.3447377383708954
# loss: 0.3422902524471283
# loss: 0.3422902524471283
# loss: 0.32890400290489197
# loss: 0.32890400290489197
# loss: 0.3207940459251404
# loss: 0.3207940459251404
# loss: 0.08572294563055038
# loss: 0.08572294563055038
# loss: 0.0819922536611557
# loss: 0.0819922536611557
# loss: 0.4019119441509247
# loss: 0.4019119441509247
# loss: 0.371029794216156
# loss: 0.371029794216156
# loss: 0.367889940738678
# loss: 0.367889940738678
# loss: 0.06748448312282562
# loss: 0.06748448312282562
# loss: 0.05678297206759453
# loss: 0.05678297206759453
# loss: 0.31033557653427124
# loss: 0.31033557653427124
# loss: 0.3608524203300476
# loss: 0.3608524203300476
# loss: 0.3409918248653412
# loss: 0.3409918248653412
# loss: 0.048827312886714935
# loss: 0.048827312886714935
# loss: 0.43385228514671326
# loss: 0.43385228514671326
# loss: 0.30791863799095154
# loss: 0.30791863799095154
# loss: 0.37382304668426514
# loss: 0.37382304668426514
# loss: 0.3854123055934906
# loss: 0.3854123055934906
# loss: 0.07247602939605713
# loss: 0.07247602939605713
# loss: 0.3620160222053528
# loss: 0.3620160222053528
# loss: 0.0915307030081749
# loss: 0.0915307030081749
# loss: 0.3654159903526306
# loss: 0.3654159903526306
# loss: 0.3447507321834564
# loss: 0.3447507321834564
# loss: 0.3405686020851135
# loss: 0.3405686020851135
# loss: 0.33398574590682983
# loss: 0.33398574590682983
# loss: 0.37722504138946533
# loss: 0.37722504138946533
# loss: 0.3659929633140564
# loss: 0.3659929633140564
# loss: 0.32039353251457214
# loss: 0.32039353251457214
# loss: 0.33591917157173157
# loss: 0.33591917157173157
# loss: 0.3501618504524231
# loss: 0.3501618504524231
# loss: 0.2585603892803192
# loss: 0.2585603892803192
# loss: 0.29604512453079224
# loss: 0.29604512453079224
# loss: 0.12261507660150528
# loss: 0.12261507660150528
# loss: 0.3495875895023346
# loss: 0.3495875895023346
# loss: 0.40249887108802795
# loss: 0.40249887108802795
# loss: 0.3538094460964203
# loss: 0.3538094460964203
# loss: 0.40684863924980164
# loss: 0.40684863924980164
# loss: 0.3589414954185486
# loss: 0.3589414954185486
# loss: 0.15987448394298553
# loss: 0.15987448394298553
# loss: 0.3491249978542328
# loss: 0.3491249978542328
# loss: 0.33034318685531616
# loss: 0.33034318685531616
# loss: 0.36407920718193054
# loss: 0.36407920718193054
# loss: 0.35518428683280945
# loss: 0.35518428683280945
# loss: 0.36006492376327515
# loss: 0.36006492376327515
# loss: 0.10256077349185944
# loss: 0.10256077349185944
# loss: 0.37106209993362427
# loss: 0.37106209993362427
# loss: 0.3493925631046295
# loss: 0.3493925631046295
# loss: 0.3340719938278198
# loss: 0.3340719938278198
# loss: 0.10606991499662399
# loss: 0.10606991499662399
# loss: 0.3261064291000366
# loss: 0.3261064291000366
# loss: 0.34364524483680725
# loss: 0.34364524483680725
# loss: 0.0941513329744339
# loss: 0.0941513329744339
# loss: 0.36577680706977844
# loss: 0.36577680706977844
# loss: 0.3838869631290436
# loss: 0.3838869631290436
# loss: 0.32910531759262085
# loss: 0.32910531759262085
# loss: 0.36575135588645935
# loss: 0.36575135588645935
# loss: 0.3322465121746063
# loss: 0.3322465121746063
# loss: 0.09163611382246017
# loss: 0.09163611382246017
# loss: 0.356737345457077
# loss: 0.356737345457077
# loss: 0.0940217450261116
# loss: 0.0940217450261116
# loss: 0.3043590784072876
# loss: 0.3043590784072876
# loss: 0.3667178750038147
# loss: 0.3667178750038147
# loss: 0.38475996255874634
# loss: 0.38475996255874634
# loss: 0.33639588952064514
# loss: 0.33639588952064514
# loss: 0.08607541024684906
# loss: 0.08607541024684906
# loss: 0.3304029405117035
# loss: 0.3304029405117035
# loss: 0.3343237340450287
# loss: 0.3343237340450287
# loss: 0.31594738364219666
# loss: 0.31594738364219666
# loss: 0.39134952425956726
# loss: 0.39134952425956726
# loss: 0.30915704369544983
# loss: 0.30915704369544983
# loss: 0.32224178314208984
# loss: 0.32224178314208984
# loss: 0.3489866554737091
# loss: 0.3489866554737091
# loss: 0.334771990776062
# loss: 0.334771990776062
# loss: 0.11569520086050034
# loss: 0.11569520086050034
# loss: 0.30683252215385437
# loss: 0.30683252215385437
# loss: 0.34523552656173706
# loss: 0.34523552656173706
# loss: 0.09644003957509995
# loss: 0.09644003957509995
# loss: 0.39085349440574646
# loss: 0.39085349440574646
# loss: 0.31143075227737427
# loss: 0.31143075227737427
# loss: 0.3083929121494293
# loss: 0.3083929121494293
# loss: 0.3213809132575989
# loss: 0.3213809132575989
# loss: 0.4041920602321625
# loss: 0.4041920602321625
# loss: 0.3012913167476654
# loss: 0.3012913167476654
# loss: 0.2795659899711609
# loss: 0.2795659899711609
# loss: 0.30964937806129456
# loss: 0.30964937806129456
# loss: 0.320976197719574
# loss: 0.320976197719574
# loss: 0.3419596552848816
# loss: 0.3419596552848816
# loss: 0.3237570524215698
# loss: 0.3237570524215698
# loss: 0.3205176591873169
# loss: 0.3205176591873169
# loss: 0.3594362139701843
# loss: 0.3594362139701843
# loss: 0.3327253460884094
# loss: 0.3327253460884094
# loss: 0.3518674671649933
# loss: 0.3518674671649933
# loss: 0.31961145997047424
# loss: 0.31961145997047424
# loss: 0.2931972146034241
# loss: 0.2931972146034241
# loss: 0.14540672302246094
# loss: 0.14540672302246094
# loss: 0.3619854152202606
# loss: 0.3619854152202606
# loss: 0.09882210940122604
# loss: 0.09882210940122604
# loss: 0.39194604754447937
# loss: 0.39194604754447937
# loss: 0.3469969928264618
# loss: 0.3469969928264618
# loss: 0.3437560200691223
# loss: 0.3437560200691223
# loss: 0.324504554271698
# loss: 0.324504554271698
# loss: 0.30564427375793457
# loss: 0.30564427375793457
# loss: 0.10633547604084015
# loss: 0.10633547604084015
# loss: 0.34427767992019653
# loss: 0.34427767992019653
# loss: 0.39942213892936707
# loss: 0.39942213892936707
# loss: 0.38104745745658875
# loss: 0.38104745745658875
# loss: 0.3506229519844055
# loss: 0.3506229519844055
# loss: 0.3758237957954407
# loss: 0.3758237957954407
# loss: 0.3292611837387085
# loss: 0.3292611837387085
# loss: 0.3360326588153839
# loss: 0.3360326588153839
# loss: 0.324253648519516
# loss: 0.324253648519516
# loss: 0.3333517909049988
# loss: 0.3333517909049988
# loss: 0.2975105047225952
# loss: 0.2975105047225952
# loss: 0.3172135055065155
# loss: 0.3172135055065155
# loss: 0.3300425112247467
# loss: 0.3300425112247467
# loss: 0.3451051414012909
# loss: 0.3451051414012909
# loss: 0.3389925956726074
# loss: 0.3389925956726074
# loss: 0.2924153506755829
# loss: 0.2924153506755829
# loss: 0.3206520080566406
# loss: 0.3206520080566406
# loss: 0.3325170874595642
# loss: 0.3325170874595642
# loss: 0.28238993883132935
# loss: 0.28238993883132935
# loss: 0.3074460029602051
# loss: 0.3074460029602051
# loss: 0.34179335832595825
# loss: 0.34179335832595825
# loss: 0.3403838574886322
# loss: 0.3403838574886322
# loss: 0.11270525306463242
# loss: 0.11270525306463242
# loss: 0.09273204207420349
# loss: 0.09273204207420349
# loss: 0.3185656666755676
# loss: 0.3185656666755676
# loss: 0.3913462460041046
# loss: 0.3913462460041046
# loss: 0.30479878187179565
# loss: 0.30479878187179565
# loss: 0.2919984757900238
# loss: 0.2919984757900238
# loss: 0.29726722836494446
# loss: 0.29726722836494446
# loss: 0.26204559206962585
# loss: 0.26204559206962585
# loss: 0.3543180525302887
# loss: 0.3543180525302887
# loss: 0.2802688777446747
# loss: 0.2802688777446747
# loss: 0.32214444875717163
# loss: 0.32214444875717163
# loss: 0.16121655702590942
# loss: 0.16121655702590942
# loss: 0.2793983519077301
# loss: 0.2793983519077301
# loss: 0.2960871458053589
# loss: 0.2960871458053589
# loss: 0.3403221666812897
# loss: 0.3403221666812897
# loss: 0.2982930541038513
# loss: 0.2982930541038513
# loss: 0.3065549433231354
# loss: 0.3065549433231354
# loss: 0.29621145129203796
# loss: 0.29621145129203796
# loss: 0.3117421567440033
# loss: 0.3117421567440033
# loss: 0.29661279916763306
# loss: 0.29661279916763306
# loss: 0.2337266206741333
# loss: 0.2337266206741333
# loss: 0.25536343455314636
# loss: 0.25536343455314636
# loss: 0.2682555615901947
# loss: 0.2682555615901947
# loss: 0.0961240902543068
# loss: 0.0961240902543068
# loss: 0.2837046980857849
# loss: 0.2837046980857849
# loss: 0.2798454761505127
# loss: 0.2798454761505127
# loss: 0.07307306677103043
# loss: 0.07307306677103043
# loss: 0.3515932261943817
# loss: 0.3515932261943817
# loss: 0.2798542380332947
# loss: 0.2798542380332947
# loss: 0.27947476506233215
# loss: 0.27947476506233215
# loss: 0.2722000777721405
# loss: 0.2722000777721405
# loss: 0.15326526761054993
# loss: 0.15326526761054993
# loss: 0.2068042904138565
# loss: 0.2068042904138565
# loss: 0.09274178743362427
# loss: 0.09274178743362427
# loss: 0.27723902463912964
# loss: 0.27723902463912964
# loss: 0.052497975528240204
# loss: 0.052497975528240204
# loss: 0.4399386942386627
# loss: 0.4399386942386627
# loss: 0.281215101480484
# loss: 0.281215101480484
# loss: 0.2703929841518402
# loss: 0.2703929841518402
# loss: 0.2681044638156891
# loss: 0.2681044638156891
# loss: 0.27825722098350525
# loss: 0.27825722098350525
# loss: 0.2621237337589264
# loss: 0.2621237337589264
# loss: 0.269763320684433
# loss: 0.269763320684433
# loss: 0.30062782764434814
# loss: 0.30062782764434814
# loss: 0.26925933361053467
# loss: 0.26925933361053467
# loss: 0.27804404497146606
# loss: 0.27804404497146606
# loss: 0.28589004278182983
# loss: 0.28589004278182983
# loss: 0.23640824854373932
# loss: 0.23640824854373932
# loss: 0.24184049665927887
# loss: 0.24184049665927887
# loss: 0.24556636810302734
# loss: 0.24556636810302734
# loss: 0.2788795232772827
# loss: 0.2788795232772827
# loss: 0.25974172353744507
# loss: 0.25974172353744507
# loss: 0.2881123423576355
# loss: 0.2881123423576355
# loss: 0.2581891417503357
# loss: 0.2581891417503357
# loss: 0.2734428346157074
# loss: 0.2734428346157074
# loss: 0.2516516149044037
# loss: 0.2516516149044037
# loss: 0.25135788321495056
# loss: 0.25135788321495056
# loss: 0.24950897693634033
# loss: 0.24950897693634033
# loss: 0.258097767829895
# loss: 0.258097767829895
# loss: 0.25211524963378906
# loss: 0.25211524963378906
# loss: 0.24018169939517975
# loss: 0.24018169939517975
# loss: 0.13929416239261627
# loss: 0.13929416239261627
# loss: 0.322797030210495
# loss: 0.322797030210495
# loss: 0.2891724109649658
# loss: 0.2891724109649658
# loss: 0.2904091775417328
# loss: 0.2904091775417328
# loss: 0.08510610461235046
# loss: 0.08510610461235046
# loss: 0.07076886296272278
# loss: 0.07076886296272278
# loss: 0.06160736456513405
# loss: 0.06160736456513405
# loss: 0.3577476441860199
# loss: 0.3577476441860199
# loss: 0.3067140579223633
# loss: 0.3067140579223633
# loss: 0.04972774535417557
# loss: 0.04972774535417557
# loss: 0.37091657519340515
# loss: 0.37091657519340515
# loss: 0.28378504514694214
# loss: 0.28378504514694214
# loss: 0.31758660078048706
# loss: 0.31758660078048706
# loss: 0.2800637483596802
# loss: 0.2800637483596802
# loss: 0.340391606092453
# loss: 0.340391606092453
# loss: 0.2702423334121704
# loss: 0.2702423334121704
# loss: 0.1111077144742012
# loss: 0.1111077144742012
# loss: 0.28129157423973083
# loss: 0.28129157423973083

# %%
# PatchTransformer の出力を 2チャネル画像 (main/glue) として可視化
model.eval()
with torch.no_grad():
    for imgs, canvases in dataloader:
        imgs = imgs.to(device)           # (B, 3, H, W)
        canvases = canvases.to(device)   # (B, 2, Hc, Wc)

        B, C, H, W = imgs.shape

        # GT キャンバスを画像サイズにリサイズ
        canvases_resized = F.interpolate(
            canvases, size=(H, W), mode="nearest"
        )  # (B, 2, H, W)

        # 予測取得
        logits = model(imgs)                 # (B, N_patches, 2)
        probs = torch.sigmoid(logits)        # (B, N_patches, 2), 0〜1
        preds = (probs > 0.5).float()        # (B, N_patches, 2), 0/1

        # 1枚だけ取り出し
        img_vis = imgs[0].cpu()                 # (3, H, W)
        canvas_vis = canvases_resized[0].cpu()  # (2, H, W)
        probs_vis = probs[0].cpu()              # (N_patches, 2)
        preds_vis = preds[0].cpu()              # (N_patches, 2)

        # パッチグリッドに並べ直してから (H, W) に拡大
        p = patch_size
        n_h = H // p
        n_w = W // p

        # (N, 2) -> (n_h, n_w, 2) -> (2, n_h, n_w)
        probs_grid = probs_vis.view(n_h, n_w, 2).permute(2, 0, 1)  # (2, n_h, n_w)
        preds_grid = preds_vis.view(n_h, n_w, 2).permute(2, 0, 1)  # (2, n_h, n_w)

        # 最近傍補間で画像サイズに拡大 → (2, H, W)
        probs_up = F.interpolate(
            probs_grid.unsqueeze(0), size=(H, W), mode="nearest"
        )[0]  # (2, H, W)
        preds_up = F.interpolate(
            preds_grid.unsqueeze(0), size=(H, W), mode="nearest"
        )[0]  # (2, H, W)

        pred_main_vis = preds_up[0]   # (H, W)
        pred_glue_vis = preds_up[1]   # (H, W)

        canvas_main_vis = canvas_vis[0]
        canvas_glue_vis = canvas_vis[1]

        from matplotlib import pyplot as plt

        fig, axes = plt.subplots(2, 3, figsize=(12, 8))

        axes[0,0].imshow(img_vis.permute(1, 2, 0).numpy())
        axes[0,0].set_title("Input Image"); axes[0,0].axis("off")

        axes[0,1].imshow(canvas_main_vis, cmap="gray")
        axes[0,1].set_title("GT Main"); axes[0,1].axis("off")

        axes[0,2].imshow(canvas_glue_vis, cmap="gray")
        axes[0,2].set_title("GT Glue"); axes[0,2].axis("off")

        axes[1,1].imshow(pred_main_vis, cmap="gray")
        axes[1,1].set_title("Pred Main (patch)"); axes[1,1].axis("off")

        axes[1,2].imshow(pred_glue_vis, cmap="gray")
        axes[1,2].set_title("Pred Glue (patch)"); axes[1,2].axis("off")

        plt.tight_layout()
        plt.show()

        break  # 1バッチだけ可視化

# %% [markdown]
# # U-Net

# %%
# filepath: c:\Users\kotat\MyPrograms\MyKuzushiji\Glue_Craft\test\initial_trial.ipynb
# ...existing code...
import torch.nn as nn

class DoubleConv(nn.Module):
    """(Conv => BN => ReLU) x2"""
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.block(x)


class UNet(nn.Module):
    def __init__(self, in_channels=3, num_classes=2, base_ch=64):
        super().__init__()
        # Encoder
        self.enc1 = DoubleConv(in_channels, base_ch)
        self.pool1 = nn.MaxPool2d(2)
        self.enc2 = DoubleConv(base_ch, base_ch * 2)
        self.pool2 = nn.MaxPool2d(2)
        self.enc3 = DoubleConv(base_ch * 2, base_ch * 4)
        self.pool3 = nn.MaxPool2d(2)
        self.enc4 = DoubleConv(base_ch * 4, base_ch * 8)
        self.pool4 = nn.MaxPool2d(2)

        # Bottleneck
        self.bottleneck = DoubleConv(base_ch * 8, base_ch * 16)

        # Decoder
        self.up4 = nn.ConvTranspose2d(base_ch * 16, base_ch * 8, kernel_size=2, stride=2)
        self.dec4 = DoubleConv(base_ch * 16, base_ch * 8)
        self.up3 = nn.ConvTranspose2d(base_ch * 8, base_ch * 4, kernel_size=2, stride=2)
        self.dec3 = DoubleConv(base_ch * 8, base_ch * 4)
        self.up2 = nn.ConvTranspose2d(base_ch * 4, base_ch * 2, kernel_size=2, stride=2)
        self.dec2 = DoubleConv(base_ch * 4, base_ch * 2)
        self.up1 = nn.ConvTranspose2d(base_ch * 2, base_ch, kernel_size=2, stride=2)
        self.dec1 = DoubleConv(base_ch * 2, base_ch)

        # 出力: num_classes チャネル (2チャネル: main/glue)
        self.out_conv = nn.Conv2d(base_ch, num_classes, kernel_size=1)

    def forward(self, x):
        # Encoder
        e1 = self.enc1(x)         # (B, 64, H, W)
        p1 = self.pool1(e1)       # (B, 64, H/2, W/2)
        e2 = self.enc2(p1)        # (B, 128, H/2, W/2)
        p2 = self.pool2(e2)       # (B, 128, H/4, W/4)
        e3 = self.enc3(p2)        # (B, 256, H/4, W/4)
        p3 = self.pool3(e3)       # (B, 256, H/8, W/8)
        e4 = self.enc4(p3)        # (B, 512, H/8, W/8)
        p4 = self.pool4(e4)       # (B, 512, H/16, W/16)

        # Bottleneck
        b = self.bottleneck(p4)   # (B, 1024, H/16, W/16)

        # Decoder
        u4 = self.up4(b)          # (B, 512, H/8, W/8)
        u4 = torch.cat([u4, e4], dim=1)  # skip connection
        d4 = self.dec4(u4)

        u3 = self.up3(d4)         # (B, 256, H/4, W/4)
        u3 = torch.cat([u3, e3], dim=1)
        d3 = self.dec3(u3)

        u2 = self.up2(d3)         # (B, 128, H/2, W/2)
        u2 = torch.cat([u2, e2], dim=1)
        d2 = self.dec2(u2)

        u1 = self.up1(d2)         # (B, 64, H, W)
        u1 = torch.cat([u1, e1], dim=1)
        d1 = self.dec1(u1)

        logits = self.out_conv(d1)  # (B, num_classes, H, W)
        return logits
# ...existing code...

# %% [markdown]
# ## 学習

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

patch_size = 256

model = UNet(
    in_channels=3,
    num_classes=2,   # 出力 2チャネル: main, glue
    base_ch=64
).to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

history = {'train_loss':[], 'val_loss':[]}

ckpt_dir = 'checkpoints_UNet'
os.makedirs(ckpt_dir, exist_ok=True)

num_epochs = 100
for epoch in range(num_epochs):  
    model.train()
    running_loss = 0.0
    n_batches = 0
    
    for imgs, canvases in train_dataloader:
        imgs = imgs.to(device)         # (B, 3, H, W)
        canvases = canvases.to(device) # (B, 2, Hc, Wc)

        B, C, H, W = imgs.shape

        # キャンバスを画像サイズにリサイズ → ピクセルごとの 0/1 ラベル
        target = F.interpolate(
            canvases, size=(H, W), mode="nearest"
        )  # (B, 2, H, W)

        # 順伝播
        logits = model(imgs)  # (B, 2, H, W)

        loss = criterion(logits, target.float())
        history.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        n_batches += 1

        # break 
 
    train_epoch_loss = running_loss / n_batches
    history['train_loss'].append(train_epoch_loss)

    model.eval()
    val_running_loss = 0.0
    val_n_batches = 0
    with torch.no_grad():
        for imgs, canvases in test_dataloader:
            imgs = imgs.to(device)
            canvases = canvases.to(device)

            B, C, H, W = imgs.shape
            target = F.interpolate(
                canvases, size=(H,W), mode= 'nearest'
            )

            logits = model(imgs)
            val_loss = criterion(logits, target.float())

            val_running_loss += val_loss.item()
            val_n_batches += 1
    val_epoch_loss = val_running_loss / val_n_batches
    history['val_loss'].append(val_epoch_loss)

    print(
        f'Epoch [{epoch+1}/{num_epochs}]',
        f'Train Loss: {train_epoch_loss:.4f} Val Loss: {val_epoch_loss:.4f}')

    ckpt_path = os.path.join(ckpt_dir, f'epoch_{epoch+1}.pth')
    torch.save(
        {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'history': history,
        },
        ckpt_path,
    )
    print(f'saved checkpoint: {ckpt_path}')

# ...existing code...
plt.plot(history['train_loss'], label='train')
plt.plot(history['val_loss'], label='val')
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.title("PatchTransformerSeg Loss")
plt.legend()
plt.show()

# %%
# 学習済み U-Net (2チャネル main/glue) の出力を可視化
model.eval()
with torch.no_grad():
    for imgs, canvases in dataloader:
        imgs = imgs.to(device)         # (B, 3, H, W)
        canvases = canvases.to(device) # (B, 2, Hc, Wc)

        B, C, H, W = imgs.shape

        target = F.interpolate(
            canvases, size=(H, W), mode="nearest"
        )  # (B, 2, H, W)

        logits = model(imgs)                 # (B, 2, H, W)
        probs = torch.sigmoid(logits)        # (B, 2, H, W), 0〜1
        preds = (probs > 0.5).float()        # (B, 2, H, W), 0/1

        img_vis = imgs[0].cpu()
        canvas_main_vis = target[0, 0].cpu()
        canvas_glue_vis = target[0, 1].cpu()
        pred_main_vis = preds[0, 0].cpu()
        pred_glue_vis = preds[0, 1].cpu()

        fig, axes = plt.subplots(2, 3, figsize=(12, 8))

        axes[0,0].imshow(img_vis.permute(1, 2, 0).byte())
        axes[0,0].set_title("Input Image"); axes[0,0].axis("off")

        axes[0,1].imshow(canvas_main_vis, cmap="gray")
        axes[0,1].set_title("GT Main"); axes[0,1].axis("off")

        axes[0,2].imshow(canvas_glue_vis, cmap="gray")
        axes[0,2].set_title("GT Glue"); axes[0,2].axis("off")

        axes[1,1].imshow(pred_main_vis, cmap="gray")
        axes[1,1].set_title("Pred Main"); axes[1,1].axis("off")

        axes[1,2].imshow(pred_glue_vis, cmap="gray")
        axes[1,2].set_title("Pred Glue"); axes[1,2].axis("off")

        plt.tight_layout()
        plt.show()

        break

# %% [markdown]
# # TransformerSeg

# %%
class PatchTransformerSeg(nn.Module):
    def __init__(self, img_channels=3, patch_size=256, d_model=256,
                 nhead=8, num_layers=4, num_classes=2):
        super().__init__()
        self.patch_size = patch_size
        self.img_channels = img_channels

        patch_dim = img_channels * patch_size * patch_size
        self.patch_embed = nn.Linear(patch_dim, d_model)

        # 位置埋め込み（最大パッチ数を仮に 256 としておく）
        max_patches = 256
        self.pos_embed = nn.Parameter(torch.zeros(1, max_patches, d_model))

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=nhead, batch_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        # --- ここから UpConv デコーダ ---
        # パッチグリッド (n_h, n_w) から段階的に解像度を上げる
        # 出力解像度は最後に F.interpolate で (H, W) に揃えるので、
        # アップサンプリング回数はそこまで厳密でなくてよいです。
        self.up1 = nn.ConvTranspose2d(d_model, d_model // 2, kernel_size=2, stride=2)
        self.up2 = nn.ConvTranspose2d(d_model // 2, d_model // 4, kernel_size=2, stride=2)
        self.up3 = nn.ConvTranspose2d(d_model // 4, d_model // 8, kernel_size=2, stride=2)

        self.dec_conv = nn.Sequential(
            nn.Conv2d(d_model // 8, d_model // 8, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(d_model // 8, num_classes, kernel_size=1)
        )

    def forward(self, img):
        """
        img: (B, 3, H, W)
        return: logits: (B, num_classes, H, W)  # ここでは num_classes=2 (main, glue)
        """
        B, C, H, W = img.shape
        p = self.patch_size

        assert H % p == 0 and W % p == 0
        n_h = H // p
        n_w = W // p
        n_patches = n_h * n_w
        assert n_patches <= self.pos_embed.size(1), "max_patches を増やす必要あり"

        # (B, C, H, W) -> パッチ列 (B, N, C*p*p)
        x = img.unfold(2, p, p).unfold(3, p, p)  # (B, C, n_h, n_w, p, p)
        x = x.contiguous().view(B, C, n_h * n_w, p * p)  # (B, C, N, p*p)
        x = x.permute(0, 2, 1, 3).contiguous().view(B, n_patches, -1)  # (B, N, C*p*p)

        # 線形埋め込み
        x = self.patch_embed(x)  # (B, N, d_model)

        # 位置埋め込み
        x = x + self.pos_embed[:, :n_patches, :]

        # Transformer Encoder
        x = self.encoder(x)  # (B, N, d_model)

        # パッチグリッドに戻す -> (B, d_model, n_h, n_w)
        x = x.view(B, n_h, n_w, -1).permute(0, 3, 1, 2).contiguous()

        x = F.relu(self.up1(x))  # (B, d_model//2, n_h*2,   n_w*2)
        x = F.relu(self.up2(x))  # (B, d_model//4, n_h*4,   n_w*4)
        x = F.relu(self.up3(x))  # (B, d_model//8, n_h*8,   n_w*8)

        # 2チャネル (main, glue) ロジット
        logits_low = self.dec_conv(x)  # (B, 2, H_low, W_low)

        # 最終的に元画像サイズにリサイズ
        logits = F.interpolate(logits_low, size=(H, W), mode="bilinear", align_corners=False)

        return logits

# %% [markdown]
# ## 学習

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

patch_size = 256
model = PatchTransformerSeg(
    img_channels=3,
    patch_size=patch_size,
    d_model=256,
    nhead=8,
    num_layers=4,
    num_classes=2   # main, glue
).to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

history = {'train_loss':[], 'val_loss':[]}

ckpt_dir = 'checkpoints_PatchTransformerSeg'
os.makedirs(ckpt_dir, exist_ok=True)

num_epochs = 100
for epoch in range(num_epochs):  
    model.train()
    running_loss = 0.0
    n_batches = 0
    
    for imgs, canvases in train_dataloader:
        imgs = imgs.to(device)         # (B, 3, H, W)
        canvases = canvases.to(device) # (B, 2, Hc, Wc)

        B, C, H, W = imgs.shape

        # キャンバスを画像サイズにリサイズ → ピクセルごとの 0/1 ラベル
        target = F.interpolate(
            canvases, size=(H, W), mode="nearest"
        )  # (B, 2, H, W)

        # 順伝播
        logits = model(imgs)  # (B, 2, H, W)

        loss = criterion(logits, target.float())
        history.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        n_batches += 1

        # break 
 
    train_epoch_loss = running_loss / n_batches
    history['train_loss'].append(train_epoch_loss)

    model.eval()
    val_running_loss = 0.0
    val_n_batches = 0
    with torch.no_grad():
        for imgs, canvases in test_dataloader:
            imgs = imgs.to(device)
            canvases = canvases.to(device)

            B, C, H, W = imgs.shape
            target = F.interpolate(
                canvases, size=(H,W), mode= 'nearest'
            )

            logits = model(imgs)
            val_loss = criterion(logits, target.float())

            val_running_loss += val_loss.item()
            val_n_batches += 1
    val_epoch_loss = val_running_loss / val_n_batches
    history['val_loss'].append(val_epoch_loss)

    print(
        f'Epoch [{epoch+1}/{num_epochs}]',
        f'Train Loss: {train_epoch_loss:.4f} Val Loss: {val_epoch_loss:.4f}')

    ckpt_path = os.path.join(ckpt_dir, f'epoch_{epoch+1}.pth')
    torch.save(
        {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'history': history,
        },
        ckpt_path,
    )
    print(f'saved checkpoint: {ckpt_path}')

# ...existing code...
plt.plot(history['train_loss'], label='train')
plt.plot(history['val_loss'], label='val')
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.title("PatchTransformerSeg Loss")
plt.legend()
plt.show()
# Out:
# loss: 0.6758154630661011
# loss: 0.6719690561294556
# loss: 0.6719690561294556
# loss: 0.6714478135108948
# loss: 0.6714478135108948
# loss: 0.6709091067314148
# loss: 0.6709091067314148
# loss: 0.6699999570846558
# loss: 0.6699999570846558
# loss: 0.6724483966827393
# loss: 0.6724483966827393
# loss: 0.6693435907363892
# loss: 0.6693435907363892
# loss: 0.6679279208183289
# loss: 0.6679279208183289
# loss: 0.6678697466850281
# loss: 0.6678697466850281
# loss: 0.6665639877319336
# loss: 0.6665639877319336
# loss: 0.6684964299201965
# loss: 0.6684964299201965
# loss: 0.6675897836685181
# loss: 0.6675897836685181
# loss: 0.6636911630630493
# loss: 0.6636911630630493
# loss: 0.6656336784362793
# loss: 0.6656336784362793
# loss: 0.6611924171447754
# loss: 0.6611924171447754
# loss: 0.6613897681236267
# loss: 0.6613897681236267
# loss: 0.6623418927192688
# loss: 0.6623418927192688
# loss: 0.6593579053878784
# loss: 0.6593579053878784
# loss: 0.6580337882041931
# loss: 0.6580337882041931
# loss: 0.657265305519104
# loss: 0.657265305519104
# loss: 0.6560396552085876
# loss: 0.6560396552085876
# loss: 0.6530075073242188
# loss: 0.6530075073242188
# loss: 0.6537606120109558
# loss: 0.6537606120109558
# loss: 0.6517192125320435
# loss: 0.6517192125320435
# loss: 0.6498889923095703
# loss: 0.6498889923095703
# loss: 0.6481689810752869
# loss: 0.6481689810752869
# loss: 0.6465886235237122
# loss: 0.6465886235237122
# loss: 0.6442210674285889
# loss: 0.6442210674285889
# loss: 0.6408458352088928
# loss: 0.6408458352088928
# loss: 0.6400923132896423
# loss: 0.6400923132896423
# loss: 0.6376797556877136
# loss: 0.6376797556877136
# loss: 0.6318333745002747
# loss: 0.6318333745002747
# loss: 0.6284156441688538
# loss: 0.6284156441688538
# loss: 0.6289856433868408
# loss: 0.6289856433868408
# loss: 0.6207519173622131
# loss: 0.6207519173622131
# loss: 0.6207453608512878
# loss: 0.6207453608512878
# loss: 0.6150331497192383
# loss: 0.6150331497192383
# loss: 0.61356121301651
# loss: 0.61356121301651
# loss: 0.6092857718467712
# loss: 0.6092857718467712
# loss: 0.6010052561759949
# loss: 0.6010052561759949
# loss: 0.5981345176696777
# loss: 0.5981345176696777
# loss: 0.5935707092285156
# loss: 0.5935707092285156
# loss: 0.5877947211265564
# loss: 0.5877947211265564
# loss: 0.5818617939949036
# loss: 0.5818617939949036
# loss: 0.579755425453186
# loss: 0.579755425453186
# loss: 0.5702522993087769
# loss: 0.5702522993087769
# loss: 0.5602577924728394
# loss: 0.5602577924728394
# loss: 0.5340465307235718
# loss: 0.5340465307235718
# loss: 0.5446361303329468
# loss: 0.5446361303329468
# loss: 0.5412750244140625
# loss: 0.5412750244140625
# loss: 0.5266944766044617
# loss: 0.5266944766044617
# loss: 0.5197628140449524
# loss: 0.5197628140449524
# loss: 0.5137944221496582
# loss: 0.5137944221496582
# loss: 0.49714571237564087
# loss: 0.49714571237564087
# loss: 0.48595014214515686
# loss: 0.48595014214515686
# loss: 0.4769507944583893
# loss: 0.4769507944583893
# loss: 0.4204846918582916
# loss: 0.4204846918582916
# loss: 0.4587157368659973
# loss: 0.4587157368659973
# loss: 0.4356084167957306
# loss: 0.4356084167957306
# loss: 0.447094202041626
# loss: 0.447094202041626
# loss: 0.4249386489391327
# loss: 0.4249386489391327
# loss: 0.4047190546989441
# loss: 0.4047190546989441
# loss: 0.40357285737991333
# loss: 0.40357285737991333
# loss: 0.3770255446434021
# loss: 0.3770255446434021
# loss: 0.3814094662666321
# loss: 0.3814094662666321
# loss: 0.3598775267601013
# loss: 0.3598775267601013
# loss: 0.3602336049079895
# loss: 0.3602336049079895
# loss: 0.23584109544754028
# loss: 0.23584109544754028
# loss: 0.3260094225406647
# loss: 0.3260094225406647
# loss: 0.3182442784309387
# loss: 0.3182442784309387
# loss: 0.18772655725479126
# loss: 0.18772655725479126
# loss: 0.3017222583293915
# loss: 0.3017222583293915
# loss: 0.3034589886665344
# loss: 0.3034589886665344
# loss: 0.30619531869888306
# loss: 0.30619531869888306
# loss: 0.13371466100215912
# loss: 0.13371466100215912
# loss: 0.2868196666240692
# loss: 0.2868196666240692
# loss: 0.306866854429245
# loss: 0.306866854429245
# loss: 0.29878562688827515
# loss: 0.29878562688827515
# loss: 0.09705859422683716
# loss: 0.09705859422683716
# loss: 0.29345494508743286
# loss: 0.29345494508743286
# loss: 0.25847652554512024
# loss: 0.25847652554512024
# loss: 0.3336876630783081
# loss: 0.3336876630783081
# loss: 0.2566449046134949
# loss: 0.2566449046134949
# loss: 0.33725830912590027
# loss: 0.33725830912590027
# loss: 0.3142164945602417
# loss: 0.3142164945602417
# loss: 0.298786997795105
# loss: 0.298786997795105
# loss: 0.2662461996078491
# loss: 0.2662461996078491
# loss: 0.325181245803833
# loss: 0.325181245803833
# loss: 0.25886663794517517
# loss: 0.25886663794517517
# loss: 0.30354583263397217
# loss: 0.30354583263397217
# loss: 0.11087896674871445
# loss: 0.11087896674871445
# loss: 0.09788975119590759
# loss: 0.09788975119590759
# loss: 0.263359010219574
# loss: 0.263359010219574
# loss: 0.07473713159561157
# loss: 0.07473713159561157
# loss: 0.06620500981807709
# loss: 0.06620500981807709
# loss: 0.34152355790138245
# loss: 0.34152355790138245
# loss: 0.29544422030448914
# loss: 0.29544422030448914
# loss: 0.29818034172058105
# loss: 0.29818034172058105
# loss: 0.31019338965415955
# loss: 0.31019338965415955
# loss: 0.29040712118148804
# loss: 0.29040712118148804
# loss: 0.3024076819419861
# loss: 0.3024076819419861
# loss: 0.3211267590522766
# loss: 0.3211267590522766
# loss: 0.05966351181268692
# loss: 0.05966351181268692
# loss: 0.24805080890655518
# loss: 0.24805080890655518
# loss: 0.2927401661872864
# loss: 0.2927401661872864
# loss: 0.26892250776290894
# loss: 0.26892250776290894
# loss: 0.25655022263526917
# loss: 0.25655022263526917
# loss: 0.24857856333255768
# loss: 0.24857856333255768
# loss: 0.3295327425003052
# loss: 0.3295327425003052
# loss: 0.239690899848938
# loss: 0.239690899848938
# loss: 0.27972346544265747
# loss: 0.27972346544265747
# loss: 0.14748728275299072
# loss: 0.14748728275299072
# loss: 0.2536924481391907
# loss: 0.2536924481391907
# loss: 0.26675426959991455
# loss: 0.26675426959991455
# loss: 0.09749213606119156
# loss: 0.09749213606119156
# loss: 0.2930619418621063
# loss: 0.2930619418621063
# loss: 0.29361486434936523
# loss: 0.29361486434936523
# loss: 0.2960878312587738
# loss: 0.2960878312587738
# loss: 0.28858882188796997
# loss: 0.28858882188796997
# loss: 0.08927645534276962
# loss: 0.08927645534276962
# loss: 0.2799700200557709
# loss: 0.2799700200557709
# loss: 0.29473966360092163
# loss: 0.29473966360092163
# loss: 0.2964792847633362
# loss: 0.2964792847633362
# loss: 0.28474268317222595
# loss: 0.28474268317222595
# loss: 0.29481983184814453
# loss: 0.29481983184814453
# loss: 0.3104191720485687
# loss: 0.3104191720485687
# loss: 0.2554241418838501
# loss: 0.2554241418838501
# loss: 0.2979772686958313
# loss: 0.2979772686958313
# loss: 0.14281830191612244
# loss: 0.14281830191612244
# loss: 0.2921345829963684
# loss: 0.2921345829963684
# loss: 0.25313687324523926
# loss: 0.25313687324523926
# loss: 0.2647998034954071
# loss: 0.2647998034954071
# loss: 0.2839273512363434
# loss: 0.2839273512363434
# loss: 0.2813277542591095
# loss: 0.2813277542591095
# loss: 0.14529311656951904
# loss: 0.14529311656951904
# loss: 0.255072683095932
# loss: 0.255072683095932
# loss: 0.26463863253593445
# loss: 0.26463863253593445
# loss: 0.2658771872520447
# loss: 0.2658771872520447
# loss: 0.2725848853588104
# loss: 0.2725848853588104
# loss: 0.09108762443065643
# loss: 0.09108762443065643
# loss: 0.2541550099849701
# loss: 0.2541550099849701
# loss: 0.2768223285675049
# loss: 0.2768223285675049
# loss: 0.2758857309818268
# loss: 0.2758857309818268
# loss: 0.2550751268863678
# loss: 0.2550751268863678
# loss: 0.2662728428840637
# loss: 0.2662728428840637
# loss: 0.25471052527427673
# loss: 0.25471052527427673
# loss: 0.26979324221611023
# loss: 0.26979324221611023
# loss: 0.08277352899312973
# loss: 0.08277352899312973
# loss: 0.08101195842027664
# loss: 0.08101195842027664
# loss: 0.26549601554870605
# loss: 0.26549601554870605
# loss: 0.2555222511291504
# loss: 0.2555222511291504
# loss: 0.25615936517715454
# loss: 0.25615936517715454
# loss: 0.07240720838308334
# loss: 0.07240720838308334
# loss: 0.25598517060279846
# loss: 0.25598517060279846
# loss: 0.2729959189891815
# loss: 0.2729959189891815
# loss: 0.33549848198890686
# loss: 0.33549848198890686
# loss: 0.3279787003993988
# loss: 0.3279787003993988
# loss: 0.0678657591342926
# loss: 0.0678657591342926
# loss: 0.2555980086326599
# loss: 0.2555980086326599
# loss: 0.25068196654319763
# loss: 0.25068196654319763
# loss: 0.27708184719085693
# loss: 0.27708184719085693
# loss: 0.3378831148147583
# loss: 0.3378831148147583
# loss: 0.2689807116985321
# loss: 0.2689807116985321
# loss: 0.2878582179546356
# loss: 0.2878582179546356
# loss: 0.2933024764060974
# loss: 0.2933024764060974
# loss: 0.29815277457237244
# loss: 0.29815277457237244
# loss: 0.3294616639614105
# loss: 0.3294616639614105
# loss: 0.3203951418399811
# loss: 0.3203951418399811
# loss: 0.35028859972953796
# loss: 0.35028859972953796
# loss: 0.2491261214017868
# loss: 0.2491261214017868
# loss: 0.09810862690210342
# loss: 0.09810862690210342
# loss: 0.09990563243627548
# loss: 0.09990563243627548
# loss: 0.29753753542900085
# loss: 0.29753753542900085
# loss: 0.09962600469589233
# loss: 0.09962600469589233
# loss: 0.09739134460687637
# loss: 0.09739134460687637
# loss: 0.0936167985200882
# loss: 0.0936167985200882
# loss: 0.2715667486190796
# loss: 0.2715667486190796
# loss: 0.2720259428024292
# loss: 0.2720259428024292
# loss: 0.2587713599205017
# loss: 0.2587713599205017
# loss: 0.2732555568218231
# loss: 0.2732555568218231
# loss: 0.27759090065956116
# loss: 0.27759090065956116
# loss: 0.29832562804222107
# loss: 0.29832562804222107
# loss: 0.30049440264701843
# loss: 0.30049440264701843
# loss: 0.23354320228099823
# loss: 0.23354320228099823
# loss: 0.30531808733940125
# loss: 0.30531808733940125
# loss: 0.32496610283851624
# loss: 0.32496610283851624
# loss: 0.26390397548675537
# loss: 0.26390397548675537
# loss: 0.25473740696907043
# loss: 0.25473740696907043
# loss: 0.24920181930065155
# loss: 0.24920181930065155
# loss: 0.25903576612472534
# loss: 0.25903576612472534
# loss: 0.2765413820743561
# loss: 0.2765413820743561
# loss: 0.08358027040958405
# loss: 0.08358027040958405
# loss: 0.24735312163829803
# loss: 0.24735312163829803
# loss: 0.2584795355796814
# loss: 0.2584795355796814
# loss: 0.32749998569488525
# loss: 0.32749998569488525
# loss: 0.08477089554071426
# loss: 0.08477089554071426
# loss: 0.253959059715271
# loss: 0.253959059715271
# loss: 0.285936564207077
# loss: 0.285936564207077
# loss: 0.28545457124710083
# loss: 0.28545457124710083
# loss: 0.2585645318031311
# loss: 0.2585645318031311

# %% [markdown]
# ## 検証

# %%
# PatchTransformerSeg の出力 (2チャネル main/glue) を可視化
model.eval()
with torch.no_grad():
    for imgs, canvases in dataloader:
        imgs = imgs.to(device)         # (B, 3, H, W)
        canvases = canvases.to(device) # (B, 2, Hc, Wc)

        B, C, H, W = imgs.shape

        # GT キャンバスを画像サイズにリサイズ
        target = F.interpolate(
            canvases, size=(H, W), mode="nearest"
        )  # (B, 2, H, W)

        # 予測取得
        logits = model(imgs)                # (B, 2, H, W)
        probs  = torch.sigmoid(logits)      # (B, 2, H, W)
        preds  = (probs > 0.5).float()      # (B, 2, H, W)

        # 1枚だけ取り出し
        img_vis          = imgs[0].cpu()
        canvas_main_vis  = target[0, 0].cpu()
        canvas_glue_vis  = target[0, 1].cpu()
        pred_main_vis    = preds[0, 0].cpu()
        pred_glue_vis    = preds[0, 1].cpu()

        from matplotlib import pyplot as plt

        fig, axes = plt.subplots(2, 3, figsize=(12, 8))

        axes[0,0].imshow(img_vis.permute(1, 2, 0))
        axes[0,0].set_title("Input Image"); axes[0,0].axis("off")

        axes[0,1].imshow(canvas_main_vis, cmap="gray")
        axes[0,1].set_title("GT Main"); axes[0,1].axis("off")

        axes[0,2].imshow(canvas_glue_vis, cmap="gray")
        axes[0,2].set_title("GT Glue"); axes[0,2].axis("off")

        axes[1,1].imshow(pred_main_vis, cmap="gray")
        axes[1,1].set_title("Pred Main"); axes[1,1].axis("off")

        axes[1,2].imshow(pred_glue_vis, cmap="gray")
        axes[1,2].set_title("Pred Glue"); axes[1,2].axis("off")

        plt.tight_layout()
        plt.show()

        break  # 1バッチだけ表示

# %% [markdown]
# # TransformerSep

# %%
import torch.nn as nn

class PatchTransformerSep(nn.Module):
    def __init__(self, img_channels=3, big_patch_size=256, vit_patch_size=16,
                 d_model=256, nhead=8, num_layers=4, num_classes=2):
        super().__init__()
        self.big_patch_size = big_patch_size     # 256
        self.vit_patch_size = vit_patch_size     # 16
        self.img_channels = img_channels

        # ViT 内部でのパッチの次元 (3 * 16 * 16)
        inner_patch_dim = img_channels * vit_patch_size * vit_patch_size
        self.patch_embed = nn.Linear(inner_patch_dim, d_model)

        # 各 256×256 タイルの中のトークン数 = (256/16)^2 = 256
        max_tokens = (big_patch_size // vit_patch_size) ** 2  # 256
        self.pos_embed = nn.Parameter(torch.zeros(1, max_tokens, d_model))

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=nhead, batch_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        # タイル内の 16×16 グリッドを num_classes チャネルに射影
        self.head = nn.Conv2d(d_model, num_classes, kernel_size=1)

    def forward(self, img):
        """
        img: (B, 3, H, W),  H,W は 256 の倍数を想定
        return: logits: (B, num_classes, H, W)
        """
        B, C, H, W = img.shape
        P = self.big_patch_size      # 256
        p = self.vit_patch_size      # 16

        assert H % P == 0 and W % P == 0, "H,W は big_patch_size(256) の倍数を想定"
        nH_big = H // P   # 大タイル数 (縦)
        nW_big = W // P   # 大タイル数 (横)
        n_big = nH_big * nW_big

        # --- 1. 画像を 256×256 タイルに分割 ---
        # img: (B, C, H, W)
        x = img.unfold(2, P, P).unfold(3, P, P)  # (B, C, nH_big, nW_big, P, P)
        x = x.permute(0, 2, 3, 1, 4, 5).contiguous()  # (B, nH_big, nW_big, C, P, P)
        # for i in range(x.shape[1]):
        #     for j in range(x.shape[2]):
        #         plt.imshow(x[0, i, j].permute(1, 2, 0).cpu())
        #         plt.title(f"Tile ({i}, {j})")
        #         plt.axis("off")
        #         plt.show()
        x = x.view(B * n_big, C, P, P)  # (B*n_big, C, 256, 256)  各タイルをバッチ扱い

        # --- 2. 各 256×256 タイルを 16×16 パッチに分割（ViT 方式） ---
        n_h_inner = P // p  # 16
        n_w_inner = P // p  # 16
        N_inner = n_h_inner * n_w_inner  # 256

        # x: (B*n_big, C, 256, 256)
        x = x.unfold(2, p, p).unfold(3, p, p)  # (B*n_big, C, n_h_inner, n_w_inner, p, p)
        x = x.contiguous().view(
            B * n_big, C, N_inner, p * p
        )  # (B*n_big, C, 256, 16*16)
        x = x.permute(0, 2, 1, 3).contiguous().view(
            B * n_big, N_inner, -1
        )  # (B*n_big, 256, C*p*p)

        # --- 3. ViT 埋め込み + Transformer ---
        x = self.patch_embed(x)  # (B*n_big, 256, d_model)
        x = x + self.pos_embed[:, :N_inner, :]  # 位置埋め込み
        x = self.encoder(x)      # (B*n_big, 256, d_model)

        # --- 4. タイル内 16×16 グリッドに戻して 256×256 にアップサンプル ---
        x = x.view(B * n_big, n_h_inner, n_w_inner, -1).permute(
            0, 3, 1, 2
        ).contiguous()   # (B*n_big, d_model, 16, 16)

        logits_small = self.head(x)  # (B*n_big, num_classes, 16, 16)

        # 各タイル内を 256×256 に補間
        logits_tile = F.interpolate(
            logits_small, size=(P, P), mode="bilinear", align_corners=False
        )  # (B*n_big, num_classes, 256, 256)

        # --- 5. タイルを元位置に敷き詰めて (B, num_classes, H, W) を作る ---
        logits_tile = logits_tile.view(
            B, nH_big, nW_big, -1, P, P
        )  # (B, nH_big, nW_big, num_classes, 256, 256)

        logits = logits_tile.permute(
            0, 3, 1, 4, 2, 5
        ).contiguous().view(
            B, -1, H, W
        )  # (B, num_classes, H, W)
        # for i in range(logits.shape[0]):
        #     for j in range(logits.shape[1]):
        #         plt.title(f'batch[{i}] class[{j}]')
        #         plt.imshow(logits[i][j].cpu().detach().numpy())
        #         plt.show()

        return logits

# %% [markdown]
# ## 学習

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

patch_size = 256
model = PatchTransformerSep(
    img_channels=3,
    big_patch_size=256,
    vit_patch_size=16,
    d_model=256,
    nhead=8,
    num_layers=4,
    num_classes=2
).to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

history = {'train_loss':[], 'val_loss':[]}

ckpt_dir = 'checkpoints'
os.makedirs(ckpt_dir, exist_ok=True)

num_epochs = 100
for epoch in range(num_epochs):  
    model.train()
    running_loss = 0.0
    n_batches = 0
    
    for imgs, canvases in train_dataloader:
        imgs = imgs.to(device)         # (B, 3, H, W)
        canvases = canvases.to(device) # (B, 2, Hc, Wc)

        B, C, H, W = imgs.shape

        # キャンバスを画像サイズにリサイズ → ピクセルごとの 0/1 ラベル
        target = F.interpolate(
            canvases, size=(H, W), mode="nearest"
        )  # (B, 2, H, W)

        # 順伝播
        logits = model(imgs)  # (B, 2, H, W)

        loss = criterion(logits, target.float())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        n_batches += 1

        # break  # 動作確認用; 全バッチ回したいなら消す

    train_epoch_loss = running_loss / n_batches
    history['train_loss'].append(train_epoch_loss)

    model.eval()
    val_running_loss = 0.0
    val_n_batches = 0
    with torch.no_grad():
        for imgs, canvases in test_dataloader:
            imgs = imgs.to(device)
            canvases = canvases.to(device)

            B, C, H, W = imgs.shape
            target = F.interpolate(
                canvases, size=(H,W), mode= 'nearest'
            )

            logits = model(imgs)
            val_loss = criterion(logits, target.float())

            val_running_loss += val_loss.item()
            val_n_batches += 1
    val_epoch_loss = val_running_loss / val_n_batches
    history['val_loss'].append(val_epoch_loss)

    print(
        f'Epoch [{epoch+1}/{num_epochs}]',
        f'Train Loss: {train_epoch_loss:.4f} Val Loss: {val_epoch_loss:.4f}')

    ckpt_path = os.path.join(ckpt_dir, f'patchtransformersep_epoch_{epoch+1}.pth')
    torch.save(
        {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'history': history,
        },
        ckpt_path,
    )
    print(f'saved checkpoint: {ckpt_path}')

# ...existing code...
plt.plot(history['train_loss'], label='train')
plt.plot(history['val_loss'], label='val')
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.title("PatchTransformerSeg Loss")
plt.legend()
plt.show()
# Out:
# Epoch [1/100] Train Loss: 0.2395 Val Loss: 0.2071
# saved checkpoint: checkpoints\patchtransformersep_epoch_1.pth
# Epoch [2/100] Train Loss: 0.2121 Val Loss: 0.1986
# saved checkpoint: checkpoints\patchtransformersep_epoch_2.pth
# Epoch [2/100] Train Loss: 0.2121 Val Loss: 0.1986
# saved checkpoint: checkpoints\patchtransformersep_epoch_2.pth
# Epoch [3/100] Train Loss: 0.2006 Val Loss: 0.1957
# saved checkpoint: checkpoints\patchtransformersep_epoch_3.pth
# Epoch [3/100] Train Loss: 0.2006 Val Loss: 0.1957
# saved checkpoint: checkpoints\patchtransformersep_epoch_3.pth
# Epoch [4/100] Train Loss: 0.1736 Val Loss: 0.1673
# saved checkpoint: checkpoints\patchtransformersep_epoch_4.pth
# Epoch [4/100] Train Loss: 0.1736 Val Loss: 0.1673
# saved checkpoint: checkpoints\patchtransformersep_epoch_4.pth
# Epoch [5/100] Train Loss: 0.1525 Val Loss: 0.1602
# saved checkpoint: checkpoints\patchtransformersep_epoch_5.pth
# Epoch [5/100] Train Loss: 0.1525 Val Loss: 0.1602
# saved checkpoint: checkpoints\patchtransformersep_epoch_5.pth
# Epoch [6/100] Train Loss: 0.1477 Val Loss: 0.1504
# saved checkpoint: checkpoints\patchtransformersep_epoch_6.pth
# Epoch [6/100] Train Loss: 0.1477 Val Loss: 0.1504
# saved checkpoint: checkpoints\patchtransformersep_epoch_6.pth
# Epoch [7/100] Train Loss: 0.1449 Val Loss: 0.1482
# saved checkpoint: checkpoints\patchtransformersep_epoch_7.pth
# Epoch [7/100] Train Loss: 0.1449 Val Loss: 0.1482
# saved checkpoint: checkpoints\patchtransformersep_epoch_7.pth
# Epoch [8/100] Train Loss: 0.1433 Val Loss: 0.1551
# saved checkpoint: checkpoints\patchtransformersep_epoch_8.pth
# Epoch [8/100] Train Loss: 0.1433 Val Loss: 0.1551
# saved checkpoint: checkpoints\patchtransformersep_epoch_8.pth
# Epoch [9/100] Train Loss: 0.1412 Val Loss: 0.1517
# saved checkpoint: checkpoints\patchtransformersep_epoch_9.pth
# Epoch [9/100] Train Loss: 0.1412 Val Loss: 0.1517
# saved checkpoint: checkpoints\patchtransformersep_epoch_9.pth
# Epoch [10/100] Train Loss: 0.1400 Val Loss: 0.1466
# saved checkpoint: checkpoints\patchtransformersep_epoch_10.pth
# Epoch [10/100] Train Loss: 0.1400 Val Loss: 0.1466
# saved checkpoint: checkpoints\patchtransformersep_epoch_10.pth
# Epoch [11/100] Train Loss: 0.1385 Val Loss: 0.1450
# saved checkpoint: checkpoints\patchtransformersep_epoch_11.pth
# Epoch [11/100] Train Loss: 0.1385 Val Loss: 0.1450
# saved checkpoint: checkpoints\patchtransformersep_epoch_11.pth
# Epoch [12/100] Train Loss: 0.1374 Val Loss: 0.1434
# saved checkpoint: checkpoints\patchtransformersep_epoch_12.pth
# Epoch [12/100] Train Loss: 0.1374 Val Loss: 0.1434
# saved checkpoint: checkpoints\patchtransformersep_epoch_12.pth
# Epoch [13/100] Train Loss: 0.1367 Val Loss: 0.1467
# saved checkpoint: checkpoints\patchtransformersep_epoch_13.pth
# Epoch [13/100] Train Loss: 0.1367 Val Loss: 0.1467
# saved checkpoint: checkpoints\patchtransformersep_epoch_13.pth
# Epoch [14/100] Train Loss: 0.1358 Val Loss: 0.1458
# saved checkpoint: checkpoints\patchtransformersep_epoch_14.pth
# Epoch [14/100] Train Loss: 0.1358 Val Loss: 0.1458
# saved checkpoint: checkpoints\patchtransformersep_epoch_14.pth
# Epoch [15/100] Train Loss: 0.1357 Val Loss: 0.1443
# saved checkpoint: checkpoints\patchtransformersep_epoch_15.pth
# Epoch [15/100] Train Loss: 0.1357 Val Loss: 0.1443
# saved checkpoint: checkpoints\patchtransformersep_epoch_15.pth
# Epoch [16/100] Train Loss: 0.1340 Val Loss: 0.1426
# saved checkpoint: checkpoints\patchtransformersep_epoch_16.pth
# Epoch [16/100] Train Loss: 0.1340 Val Loss: 0.1426
# saved checkpoint: checkpoints\patchtransformersep_epoch_16.pth
# Epoch [17/100] Train Loss: 0.1336 Val Loss: 0.1451
# saved checkpoint: checkpoints\patchtransformersep_epoch_17.pth
# Epoch [17/100] Train Loss: 0.1336 Val Loss: 0.1451
# saved checkpoint: checkpoints\patchtransformersep_epoch_17.pth
# Epoch [18/100] Train Loss: 0.1327 Val Loss: 0.1437
# saved checkpoint: checkpoints\patchtransformersep_epoch_18.pth
# Epoch [18/100] Train Loss: 0.1327 Val Loss: 0.1437
# saved checkpoint: checkpoints\patchtransformersep_epoch_18.pth
# Epoch [19/100] Train Loss: 0.1321 Val Loss: 0.1409
# saved checkpoint: checkpoints\patchtransformersep_epoch_19.pth
# Epoch [19/100] Train Loss: 0.1321 Val Loss: 0.1409
# saved checkpoint: checkpoints\patchtransformersep_epoch_19.pth
# Epoch [20/100] Train Loss: 0.1313 Val Loss: 0.1399
# saved checkpoint: checkpoints\patchtransformersep_epoch_20.pth
# Epoch [20/100] Train Loss: 0.1313 Val Loss: 0.1399
# saved checkpoint: checkpoints\patchtransformersep_epoch_20.pth
# Epoch [21/100] Train Loss: 0.1308 Val Loss: 0.1463
# saved checkpoint: checkpoints\patchtransformersep_epoch_21.pth
# Epoch [21/100] Train Loss: 0.1308 Val Loss: 0.1463
# saved checkpoint: checkpoints\patchtransformersep_epoch_21.pth
# Epoch [22/100] Train Loss: 0.1302 Val Loss: 0.1416
# saved checkpoint: checkpoints\patchtransformersep_epoch_22.pth
# Epoch [22/100] Train Loss: 0.1302 Val Loss: 0.1416
# saved checkpoint: checkpoints\patchtransformersep_epoch_22.pth
# Epoch [23/100] Train Loss: 0.1297 Val Loss: 0.1398
# saved checkpoint: checkpoints\patchtransformersep_epoch_23.pth
# Epoch [23/100] Train Loss: 0.1297 Val Loss: 0.1398
# saved checkpoint: checkpoints\patchtransformersep_epoch_23.pth
# Epoch [24/100] Train Loss: 0.1289 Val Loss: 0.1448
# saved checkpoint: checkpoints\patchtransformersep_epoch_24.pth
# Epoch [24/100] Train Loss: 0.1289 Val Loss: 0.1448
# saved checkpoint: checkpoints\patchtransformersep_epoch_24.pth
# Epoch [25/100] Train Loss: 0.1283 Val Loss: 0.1520
# saved checkpoint: checkpoints\patchtransformersep_epoch_25.pth
# Epoch [25/100] Train Loss: 0.1283 Val Loss: 0.1520
# saved checkpoint: checkpoints\patchtransformersep_epoch_25.pth
# Epoch [26/100] Train Loss: 0.1279 Val Loss: 0.1420
# saved checkpoint: checkpoints\patchtransformersep_epoch_26.pth
# Epoch [26/100] Train Loss: 0.1279 Val Loss: 0.1420
# saved checkpoint: checkpoints\patchtransformersep_epoch_26.pth
# Epoch [27/100] Train Loss: 0.1276 Val Loss: 0.1405
# saved checkpoint: checkpoints\patchtransformersep_epoch_27.pth
# Epoch [27/100] Train Loss: 0.1276 Val Loss: 0.1405
# saved checkpoint: checkpoints\patchtransformersep_epoch_27.pth
# Epoch [28/100] Train Loss: 0.1272 Val Loss: 0.1422
# saved checkpoint: checkpoints\patchtransformersep_epoch_28.pth
# Epoch [28/100] Train Loss: 0.1272 Val Loss: 0.1422
# saved checkpoint: checkpoints\patchtransformersep_epoch_28.pth
# Epoch [29/100] Train Loss: 0.1266 Val Loss: 0.1437
# saved checkpoint: checkpoints\patchtransformersep_epoch_29.pth
# Epoch [29/100] Train Loss: 0.1266 Val Loss: 0.1437
# saved checkpoint: checkpoints\patchtransformersep_epoch_29.pth
# Epoch [30/100] Train Loss: 0.1264 Val Loss: 0.1410
# saved checkpoint: checkpoints\patchtransformersep_epoch_30.pth
# Epoch [30/100] Train Loss: 0.1264 Val Loss: 0.1410
# saved checkpoint: checkpoints\patchtransformersep_epoch_30.pth
# Epoch [31/100] Train Loss: 0.1259 Val Loss: 0.1429
# saved checkpoint: checkpoints\patchtransformersep_epoch_31.pth
# Epoch [31/100] Train Loss: 0.1259 Val Loss: 0.1429
# saved checkpoint: checkpoints\patchtransformersep_epoch_31.pth
# Epoch [32/100] Train Loss: 0.1258 Val Loss: 0.1391
# saved checkpoint: checkpoints\patchtransformersep_epoch_32.pth
# Epoch [32/100] Train Loss: 0.1258 Val Loss: 0.1391
# saved checkpoint: checkpoints\patchtransformersep_epoch_32.pth
# Epoch [33/100] Train Loss: 0.1248 Val Loss: 0.1462
# saved checkpoint: checkpoints\patchtransformersep_epoch_33.pth
# Epoch [33/100] Train Loss: 0.1248 Val Loss: 0.1462
# saved checkpoint: checkpoints\patchtransformersep_epoch_33.pth
# Epoch [34/100] Train Loss: 0.1245 Val Loss: 0.1409
# saved checkpoint: checkpoints\patchtransformersep_epoch_34.pth
# Epoch [34/100] Train Loss: 0.1245 Val Loss: 0.1409
# saved checkpoint: checkpoints\patchtransformersep_epoch_34.pth
# Epoch [35/100] Train Loss: 0.1240 Val Loss: 0.1423
# saved checkpoint: checkpoints\patchtransformersep_epoch_35.pth
# Epoch [35/100] Train Loss: 0.1240 Val Loss: 0.1423
# saved checkpoint: checkpoints\patchtransformersep_epoch_35.pth
# Epoch [36/100] Train Loss: 0.1242 Val Loss: 0.1443
# saved checkpoint: checkpoints\patchtransformersep_epoch_36.pth
# Epoch [36/100] Train Loss: 0.1242 Val Loss: 0.1443
# saved checkpoint: checkpoints\patchtransformersep_epoch_36.pth
# Epoch [37/100] Train Loss: 0.1235 Val Loss: 0.1457
# saved checkpoint: checkpoints\patchtransformersep_epoch_37.pth
# Epoch [37/100] Train Loss: 0.1235 Val Loss: 0.1457
# saved checkpoint: checkpoints\patchtransformersep_epoch_37.pth
# Epoch [38/100] Train Loss: 0.1231 Val Loss: 0.1421
# saved checkpoint: checkpoints\patchtransformersep_epoch_38.pth
# Epoch [38/100] Train Loss: 0.1231 Val Loss: 0.1421
# saved checkpoint: checkpoints\patchtransformersep_epoch_38.pth
# Epoch [39/100] Train Loss: 0.1227 Val Loss: 0.1489
# saved checkpoint: checkpoints\patchtransformersep_epoch_39.pth
# Epoch [39/100] Train Loss: 0.1227 Val Loss: 0.1489
# saved checkpoint: checkpoints\patchtransformersep_epoch_39.pth
# Epoch [40/100] Train Loss: 0.1227 Val Loss: 0.1443
# saved checkpoint: checkpoints\patchtransformersep_epoch_40.pth
# Epoch [40/100] Train Loss: 0.1227 Val Loss: 0.1443
# saved checkpoint: checkpoints\patchtransformersep_epoch_40.pth
# Epoch [41/100] Train Loss: 0.1224 Val Loss: 0.1444
# saved checkpoint: checkpoints\patchtransformersep_epoch_41.pth
# Epoch [41/100] Train Loss: 0.1224 Val Loss: 0.1444
# saved checkpoint: checkpoints\patchtransformersep_epoch_41.pth
# Epoch [42/100] Train Loss: 0.1216 Val Loss: 0.1688
# saved checkpoint: checkpoints\patchtransformersep_epoch_42.pth
# Epoch [42/100] Train Loss: 0.1216 Val Loss: 0.1688
# saved checkpoint: checkpoints\patchtransformersep_epoch_42.pth
# Epoch [43/100] Train Loss: 0.1213 Val Loss: 0.1441
# saved checkpoint: checkpoints\patchtransformersep_epoch_43.pth
# Epoch [43/100] Train Loss: 0.1213 Val Loss: 0.1441
# saved checkpoint: checkpoints\patchtransformersep_epoch_43.pth
# Epoch [44/100] Train Loss: 0.1211 Val Loss: 0.1421
# saved checkpoint: checkpoints\patchtransformersep_epoch_44.pth
# Epoch [44/100] Train Loss: 0.1211 Val Loss: 0.1421
# saved checkpoint: checkpoints\patchtransformersep_epoch_44.pth
# Epoch [45/100] Train Loss: 0.1208 Val Loss: 0.1428
# saved checkpoint: checkpoints\patchtransformersep_epoch_45.pth
# Epoch [45/100] Train Loss: 0.1208 Val Loss: 0.1428
# saved checkpoint: checkpoints\patchtransformersep_epoch_45.pth
# Epoch [46/100] Train Loss: 0.1203 Val Loss: 0.1458
# saved checkpoint: checkpoints\patchtransformersep_epoch_46.pth
# Epoch [46/100] Train Loss: 0.1203 Val Loss: 0.1458
# saved checkpoint: checkpoints\patchtransformersep_epoch_46.pth
# Epoch [47/100] Train Loss: 0.1200 Val Loss: 0.1429
# saved checkpoint: checkpoints\patchtransformersep_epoch_47.pth
# Epoch [47/100] Train Loss: 0.1200 Val Loss: 0.1429
# saved checkpoint: checkpoints\patchtransformersep_epoch_47.pth
# Epoch [48/100] Train Loss: 0.1197 Val Loss: 0.1415
# saved checkpoint: checkpoints\patchtransformersep_epoch_48.pth
# Epoch [48/100] Train Loss: 0.1197 Val Loss: 0.1415
# saved checkpoint: checkpoints\patchtransformersep_epoch_48.pth
# Epoch [49/100] Train Loss: 0.1195 Val Loss: 0.1441
# saved checkpoint: checkpoints\patchtransformersep_epoch_49.pth
# Epoch [49/100] Train Loss: 0.1195 Val Loss: 0.1441
# saved checkpoint: checkpoints\patchtransformersep_epoch_49.pth
# Epoch [50/100] Train Loss: 0.1194 Val Loss: 0.1423
# saved checkpoint: checkpoints\patchtransformersep_epoch_50.pth
# Epoch [50/100] Train Loss: 0.1194 Val Loss: 0.1423
# saved checkpoint: checkpoints\patchtransformersep_epoch_50.pth
# Epoch [51/100] Train Loss: 0.1192 Val Loss: 0.1465
# saved checkpoint: checkpoints\patchtransformersep_epoch_51.pth
# Epoch [51/100] Train Loss: 0.1192 Val Loss: 0.1465
# saved checkpoint: checkpoints\patchtransformersep_epoch_51.pth
# Epoch [52/100] Train Loss: 0.1186 Val Loss: 0.1408
# saved checkpoint: checkpoints\patchtransformersep_epoch_52.pth
# Epoch [52/100] Train Loss: 0.1186 Val Loss: 0.1408
# saved checkpoint: checkpoints\patchtransformersep_epoch_52.pth
# Epoch [53/100] Train Loss: 0.1182 Val Loss: 0.1406
# saved checkpoint: checkpoints\patchtransformersep_epoch_53.pth
# Epoch [53/100] Train Loss: 0.1182 Val Loss: 0.1406
# saved checkpoint: checkpoints\patchtransformersep_epoch_53.pth
# Epoch [54/100] Train Loss: 0.1182 Val Loss: 0.1522
# saved checkpoint: checkpoints\patchtransformersep_epoch_54.pth
# Epoch [54/100] Train Loss: 0.1182 Val Loss: 0.1522
# saved checkpoint: checkpoints\patchtransformersep_epoch_54.pth
# Epoch [55/100] Train Loss: 0.1179 Val Loss: 0.1454
# saved checkpoint: checkpoints\patchtransformersep_epoch_55.pth
# Epoch [55/100] Train Loss: 0.1179 Val Loss: 0.1454
# saved checkpoint: checkpoints\patchtransformersep_epoch_55.pth
# Epoch [56/100] Train Loss: 0.1176 Val Loss: 0.1435
# saved checkpoint: checkpoints\patchtransformersep_epoch_56.pth
# Epoch [56/100] Train Loss: 0.1176 Val Loss: 0.1435
# saved checkpoint: checkpoints\patchtransformersep_epoch_56.pth
# Epoch [57/100] Train Loss: 0.1175 Val Loss: 0.1432
# saved checkpoint: checkpoints\patchtransformersep_epoch_57.pth
# Epoch [57/100] Train Loss: 0.1175 Val Loss: 0.1432
# saved checkpoint: checkpoints\patchtransformersep_epoch_57.pth
# Epoch [58/100] Train Loss: 0.1171 Val Loss: 0.1418
# saved checkpoint: checkpoints\patchtransformersep_epoch_58.pth
# Epoch [58/100] Train Loss: 0.1171 Val Loss: 0.1418
# saved checkpoint: checkpoints\patchtransformersep_epoch_58.pth
# Epoch [59/100] Train Loss: 0.1168 Val Loss: 0.1481
# saved checkpoint: checkpoints\patchtransformersep_epoch_59.pth
# Epoch [59/100] Train Loss: 0.1168 Val Loss: 0.1481
# saved checkpoint: checkpoints\patchtransformersep_epoch_59.pth
# Epoch [60/100] Train Loss: 0.1167 Val Loss: 0.1438
# saved checkpoint: checkpoints\patchtransformersep_epoch_60.pth
# Epoch [60/100] Train Loss: 0.1167 Val Loss: 0.1438
# saved checkpoint: checkpoints\patchtransformersep_epoch_60.pth
# Epoch [61/100] Train Loss: 0.1162 Val Loss: 0.1548
# saved checkpoint: checkpoints\patchtransformersep_epoch_61.pth
# Epoch [61/100] Train Loss: 0.1162 Val Loss: 0.1548
# saved checkpoint: checkpoints\patchtransformersep_epoch_61.pth
# Epoch [62/100] Train Loss: 0.1161 Val Loss: 0.1462
# saved checkpoint: checkpoints\patchtransformersep_epoch_62.pth
# Epoch [62/100] Train Loss: 0.1161 Val Loss: 0.1462
# saved checkpoint: checkpoints\patchtransformersep_epoch_62.pth
# Epoch [63/100] Train Loss: 0.1155 Val Loss: 0.1480
# saved checkpoint: checkpoints\patchtransformersep_epoch_63.pth
# Epoch [63/100] Train Loss: 0.1155 Val Loss: 0.1480
# saved checkpoint: checkpoints\patchtransformersep_epoch_63.pth
# Epoch [64/100] Train Loss: 0.1156 Val Loss: 0.1412
# saved checkpoint: checkpoints\patchtransformersep_epoch_64.pth
# Epoch [64/100] Train Loss: 0.1156 Val Loss: 0.1412
# saved checkpoint: checkpoints\patchtransformersep_epoch_64.pth
# Epoch [65/100] Train Loss: 0.1152 Val Loss: 0.1460
# saved checkpoint: checkpoints\patchtransformersep_epoch_65.pth
# Epoch [65/100] Train Loss: 0.1152 Val Loss: 0.1460
# saved checkpoint: checkpoints\patchtransformersep_epoch_65.pth
# Epoch [66/100] Train Loss: 0.1151 Val Loss: 0.1503
# saved checkpoint: checkpoints\patchtransformersep_epoch_66.pth
# Epoch [66/100] Train Loss: 0.1151 Val Loss: 0.1503
# saved checkpoint: checkpoints\patchtransformersep_epoch_66.pth
# Epoch [67/100] Train Loss: 0.1149 Val Loss: 0.1456
# saved checkpoint: checkpoints\patchtransformersep_epoch_67.pth
# Epoch [67/100] Train Loss: 0.1149 Val Loss: 0.1456
# saved checkpoint: checkpoints\patchtransformersep_epoch_67.pth
# Epoch [68/100] Train Loss: 0.1147 Val Loss: 0.1464
# saved checkpoint: checkpoints\patchtransformersep_epoch_68.pth
# Epoch [68/100] Train Loss: 0.1147 Val Loss: 0.1464
# saved checkpoint: checkpoints\patchtransformersep_epoch_68.pth
# Epoch [69/100] Train Loss: 0.1146 Val Loss: 0.1486
# saved checkpoint: checkpoints\patchtransformersep_epoch_69.pth
# Epoch [69/100] Train Loss: 0.1146 Val Loss: 0.1486
# saved checkpoint: checkpoints\patchtransformersep_epoch_69.pth
# Epoch [70/100] Train Loss: 0.1144 Val Loss: 0.1506
# saved checkpoint: checkpoints\patchtransformersep_epoch_70.pth
# Epoch [70/100] Train Loss: 0.1144 Val Loss: 0.1506
# saved checkpoint: checkpoints\patchtransformersep_epoch_70.pth
# Epoch [71/100] Train Loss: 0.1140 Val Loss: 0.1486
# saved checkpoint: checkpoints\patchtransformersep_epoch_71.pth
# Epoch [71/100] Train Loss: 0.1140 Val Loss: 0.1486
# saved checkpoint: checkpoints\patchtransformersep_epoch_71.pth
# Epoch [72/100] Train Loss: 0.1137 Val Loss: 0.1480
# saved checkpoint: checkpoints\patchtransformersep_epoch_72.pth
# Epoch [72/100] Train Loss: 0.1137 Val Loss: 0.1480
# saved checkpoint: checkpoints\patchtransformersep_epoch_72.pth
# Epoch [73/100] Train Loss: 0.1137 Val Loss: 0.1460
# saved checkpoint: checkpoints\patchtransformersep_epoch_73.pth
# Epoch [73/100] Train Loss: 0.1137 Val Loss: 0.1460
# saved checkpoint: checkpoints\patchtransformersep_epoch_73.pth
# Epoch [74/100] Train Loss: 0.1135 Val Loss: 0.1634
# saved checkpoint: checkpoints\patchtransformersep_epoch_74.pth
# Epoch [74/100] Train Loss: 0.1135 Val Loss: 0.1634
# saved checkpoint: checkpoints\patchtransformersep_epoch_74.pth
# Epoch [75/100] Train Loss: 0.1132 Val Loss: 0.1525
# saved checkpoint: checkpoints\patchtransformersep_epoch_75.pth
# Epoch [75/100] Train Loss: 0.1132 Val Loss: 0.1525
# saved checkpoint: checkpoints\patchtransformersep_epoch_75.pth
# Epoch [76/100] Train Loss: 0.1130 Val Loss: 0.1498
# saved checkpoint: checkpoints\patchtransformersep_epoch_76.pth
# Epoch [76/100] Train Loss: 0.1130 Val Loss: 0.1498
# saved checkpoint: checkpoints\patchtransformersep_epoch_76.pth
# Epoch [77/100] Train Loss: 0.1128 Val Loss: 0.1528
# saved checkpoint: checkpoints\patchtransformersep_epoch_77.pth
# Epoch [77/100] Train Loss: 0.1128 Val Loss: 0.1528
# saved checkpoint: checkpoints\patchtransformersep_epoch_77.pth
# Epoch [78/100] Train Loss: 0.1126 Val Loss: 0.1466
# saved checkpoint: checkpoints\patchtransformersep_epoch_78.pth
# Epoch [78/100] Train Loss: 0.1126 Val Loss: 0.1466
# saved checkpoint: checkpoints\patchtransformersep_epoch_78.pth
# Epoch [79/100] Train Loss: 0.1123 Val Loss: 0.1630
# saved checkpoint: checkpoints\patchtransformersep_epoch_79.pth
# Epoch [79/100] Train Loss: 0.1123 Val Loss: 0.1630
# saved checkpoint: checkpoints\patchtransformersep_epoch_79.pth
# Epoch [80/100] Train Loss: 0.1121 Val Loss: 0.1568
# saved checkpoint: checkpoints\patchtransformersep_epoch_80.pth
# Epoch [80/100] Train Loss: 0.1121 Val Loss: 0.1568
# saved checkpoint: checkpoints\patchtransformersep_epoch_80.pth
# Epoch [81/100] Train Loss: 0.1121 Val Loss: 0.1535
# saved checkpoint: checkpoints\patchtransformersep_epoch_81.pth
# Epoch [81/100] Train Loss: 0.1121 Val Loss: 0.1535
# saved checkpoint: checkpoints\patchtransformersep_epoch_81.pth
# Epoch [82/100] Train Loss: 0.1120 Val Loss: 0.1541
# saved checkpoint: checkpoints\patchtransformersep_epoch_82.pth
# Epoch [82/100] Train Loss: 0.1120 Val Loss: 0.1541
# saved checkpoint: checkpoints\patchtransformersep_epoch_82.pth
# Epoch [83/100] Train Loss: 0.1116 Val Loss: 0.1519
# saved checkpoint: checkpoints\patchtransformersep_epoch_83.pth
# Epoch [83/100] Train Loss: 0.1116 Val Loss: 0.1519
# saved checkpoint: checkpoints\patchtransformersep_epoch_83.pth
# Epoch [84/100] Train Loss: 0.1116 Val Loss: 0.1533
# saved checkpoint: checkpoints\patchtransformersep_epoch_84.pth
# Epoch [84/100] Train Loss: 0.1116 Val Loss: 0.1533
# saved checkpoint: checkpoints\patchtransformersep_epoch_84.pth
# Epoch [85/100] Train Loss: 0.1113 Val Loss: 0.1509
# saved checkpoint: checkpoints\patchtransformersep_epoch_85.pth
# Epoch [85/100] Train Loss: 0.1113 Val Loss: 0.1509
# saved checkpoint: checkpoints\patchtransformersep_epoch_85.pth
# Epoch [86/100] Train Loss: 0.1111 Val Loss: 0.1461
# saved checkpoint: checkpoints\patchtransformersep_epoch_86.pth
# Epoch [86/100] Train Loss: 0.1111 Val Loss: 0.1461
# saved checkpoint: checkpoints\patchtransformersep_epoch_86.pth
# Epoch [87/100] Train Loss: 0.1111 Val Loss: 0.1514
# saved checkpoint: checkpoints\patchtransformersep_epoch_87.pth
# Epoch [87/100] Train Loss: 0.1111 Val Loss: 0.1514
# saved checkpoint: checkpoints\patchtransformersep_epoch_87.pth
# Epoch [88/100] Train Loss: 0.1106 Val Loss: 0.1526
# saved checkpoint: checkpoints\patchtransformersep_epoch_88.pth
# Epoch [88/100] Train Loss: 0.1106 Val Loss: 0.1526
# saved checkpoint: checkpoints\patchtransformersep_epoch_88.pth
# Epoch [89/100] Train Loss: 0.1107 Val Loss: 0.1577
# saved checkpoint: checkpoints\patchtransformersep_epoch_89.pth
# Epoch [89/100] Train Loss: 0.1107 Val Loss: 0.1577
# saved checkpoint: checkpoints\patchtransformersep_epoch_89.pth
# Epoch [90/100] Train Loss: 0.1103 Val Loss: 0.1539
# saved checkpoint: checkpoints\patchtransformersep_epoch_90.pth
# Epoch [90/100] Train Loss: 0.1103 Val Loss: 0.1539
# saved checkpoint: checkpoints\patchtransformersep_epoch_90.pth
# Epoch [91/100] Train Loss: 0.1102 Val Loss: 0.1575
# saved checkpoint: checkpoints\patchtransformersep_epoch_91.pth
# Epoch [91/100] Train Loss: 0.1102 Val Loss: 0.1575
# saved checkpoint: checkpoints\patchtransformersep_epoch_91.pth
# Epoch [92/100] Train Loss: 0.1099 Val Loss: 0.1524
# saved checkpoint: checkpoints\patchtransformersep_epoch_92.pth
# Epoch [92/100] Train Loss: 0.1099 Val Loss: 0.1524
# saved checkpoint: checkpoints\patchtransformersep_epoch_92.pth
# Epoch [93/100] Train Loss: 0.1099 Val Loss: 0.1553
# saved checkpoint: checkpoints\patchtransformersep_epoch_93.pth
# Epoch [93/100] Train Loss: 0.1099 Val Loss: 0.1553
# saved checkpoint: checkpoints\patchtransformersep_epoch_93.pth
# Epoch [94/100] Train Loss: 0.1100 Val Loss: 0.1507
# saved checkpoint: checkpoints\patchtransformersep_epoch_94.pth
# Epoch [94/100] Train Loss: 0.1100 Val Loss: 0.1507
# saved checkpoint: checkpoints\patchtransformersep_epoch_94.pth
# Epoch [95/100] Train Loss: 0.1098 Val Loss: 0.1540
# saved checkpoint: checkpoints\patchtransformersep_epoch_95.pth
# Epoch [95/100] Train Loss: 0.1098 Val Loss: 0.1540
# saved checkpoint: checkpoints\patchtransformersep_epoch_95.pth
# Epoch [96/100] Train Loss: 0.1094 Val Loss: 0.1579
# saved checkpoint: checkpoints\patchtransformersep_epoch_96.pth
# Epoch [96/100] Train Loss: 0.1094 Val Loss: 0.1579
# saved checkpoint: checkpoints\patchtransformersep_epoch_96.pth
# Epoch [97/100] Train Loss: 0.1093 Val Loss: 0.1576
# saved checkpoint: checkpoints\patchtransformersep_epoch_97.pth
# Epoch [97/100] Train Loss: 0.1093 Val Loss: 0.1576
# saved checkpoint: checkpoints\patchtransformersep_epoch_97.pth
# Epoch [98/100] Train Loss: 0.1090 Val Loss: 0.1536
# saved checkpoint: checkpoints\patchtransformersep_epoch_98.pth
# Epoch [98/100] Train Loss: 0.1090 Val Loss: 0.1536
# saved checkpoint: checkpoints\patchtransformersep_epoch_98.pth
# Epoch [99/100] Train Loss: 0.1088 Val Loss: 0.1536
# saved checkpoint: checkpoints\patchtransformersep_epoch_99.pth
# Epoch [99/100] Train Loss: 0.1088 Val Loss: 0.1536
# saved checkpoint: checkpoints\patchtransformersep_epoch_99.pth
# Epoch [100/100] Train Loss: 0.1086 Val Loss: 0.1556
# saved checkpoint: checkpoints\patchtransformersep_epoch_100.pth
# Epoch [100/100] Train Loss: 0.1086 Val Loss: 0.1556
# saved checkpoint: checkpoints\patchtransformersep_epoch_100.pth

# %% [markdown]
# ## 検証

# %%
# PatchTransformerSeg の出力 (2チャネル main/glue) を可視化
ckpt_path = "checkpoints/patchtransformersep_epoch_99.pth"  # 読みたいファイル
checkpoint = torch.load(ckpt_path, map_location=device)

model.load_state_dict(checkpoint["model_state_dict"])
optimizer.load_state_dict(checkpoint["optimizer_state_dict"])

model.eval()
with torch.no_grad():
    for imgs, canvases in test_dataloader:
        imgs = imgs.to(device)         # (B, 3, H, W)
        canvases = canvases.to(device) # (B, 2, Hc, Wc)

        B, C, H, W = imgs.shape

        # GT キャンバスを画像サイズにリサイズ
        target = F.interpolate(
            canvases, size=(H, W), mode="nearest"
        )  # (B, 2, H, W)

        # 予測取得
        logits = model(imgs)                # (B, 2, H, W)
        probs  = torch.sigmoid(logits)      # (B, 2, H, W)
        preds  = (probs > 0.5).float()      # (B, 2, H, W)

        # 1枚だけ取り出し
        img_vis          = imgs[0].cpu()
        canvas_main_vis  = target[0, 0].cpu()
        canvas_glue_vis  = target[0, 1].cpu()
        pred_main_vis    = preds[0, 0].cpu()
        pred_glue_vis    = preds[0, 1].cpu()

        from matplotlib import pyplot as plt

        fig, axes = plt.subplots(2, 3, figsize=(12, 8))

        axes[0,0].imshow(img_vis.permute(1, 2, 0))
        axes[0,0].set_title("Input Image"); axes[0,0].axis("off")

        axes[0,1].imshow(canvas_main_vis, cmap="gray")
        axes[0,1].set_title("GT Main"); axes[0,1].axis("off")

        axes[0,2].imshow(canvas_glue_vis, cmap="gray")
        axes[0,2].set_title("GT Glue"); axes[0,2].axis("off")

        axes[1,1].imshow(pred_main_vis, cmap="gray")
        axes[1,1].set_title("Pred Main"); axes[1,1].axis("off")

        axes[1,2].imshow(pred_glue_vis, cmap="gray")
        axes[1,2].set_title("Pred Glue"); axes[1,2].axis("off")

        plt.tight_layout()
        plt.show()

        # break  # 1バッチだけ表示

# %%
# PatchTransformerSeg の出力 (2チャネル main/glue) を可視化
import torch 

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

patch_size = 256
model = PatchTransformerSep(
    img_channels=3,
    big_patch_size=256,
    vit_patch_size=16,
    d_model=256,
    nhead=8,
    num_layers=4,
    num_classes=2
).to(device)
ckpt_path = "checkpoints/patchtransformersep_epoch_99.pth"  # 読みたいファイル
checkpoint = torch.load(ckpt_path, map_location=device)

criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
model.load_state_dict(checkpoint["model_state_dict"])
optimizer.load_state_dict(checkpoint["optimizer_state_dict"])

model.eval()
with torch.no_grad():
    for imgs, canvases in test_dataloader:
        imgs = imgs.to(device)         # (B, 3, H, W)
        canvases = canvases.to(device) # (B, 2, Hc, Wc)

        B, C, H, W = imgs.shape

        # GT キャンバスを画像サイズにリサイズ
        target = F.interpolate(
            canvases, size=(H, W), mode="nearest"
        )  # (B, 2, H, W)

        # 予測取得
        logits = model(imgs)                # (B, 2, H, W)
        probs  = torch.sigmoid(logits)      # (B, 2, H, W)
        preds  = (probs > 0.5).float()      # (B, 2, H, W)

        # 1枚だけ取り出し
        img_vis          = imgs[0].cpu()
        canvas_main_vis  = target[0, 0].cpu()
        canvas_glue_vis  = target[0, 1].cpu()
        pred_main_vis    = preds[0, 0].cpu()
        pred_glue_vis    = preds[0, 1].cpu()

        from matplotlib import pyplot as plt
        fig, axes = plt.subplots(2, 3, figsize=(12, 8))

        axes[0,0].imshow(img_vis.permute(1, 2, 0))
        axes[0,0].set_title("Input Image"); axes[0,0].axis("off")

        axes[0,1].imshow(canvas_main_vis, cmap="gray")
        axes[0,1].set_title("GT Main"); axes[0,1].axis("off")

        axes[0,2].imshow(canvas_glue_vis, cmap="gray")
        axes[0,2].set_title("GT Glue"); axes[0,2].axis("off")

        # 入力 + Pred Main を重ねて表示
        axes[1,1].imshow(img_vis.permute(1, 2, 0))
        axes[1,1].imshow(pred_main_vis, cmap="Reds", alpha=0.4)
        axes[1,1].set_title("Input + Pred Main"); axes[1,1].axis("off")

        # 入力 + Pred Glue を重ねて表示
        axes[1,2].imshow(img_vis.permute(1, 2, 0))
        axes[1,2].imshow(pred_glue_vis, cmap="Reds", alpha=0.4)
        axes[1,2].set_title("Input + Pred Glue"); axes[1,2].axis("off")

        plt.tight_layout()
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 26
#      24 model.eval()
#      25 with torch.no_grad():
# ---> 26     for imgs, canvases in test_dataloader:
#      27         imgs = imgs.to(device)         # (B, 3, H, W)
#      28         canvases = canvases.to(device) # (B, 2, Hc, Wc)
#
# NameError: name 'test_dataloader' is not defined
